# %% [markdown]
# # CME193 project - Seismic inversion using machine learning
#
# ## Submitted by Vishal Das
#
# In this project, I used 1D convolutional neural networks to predict acoustic impedance from given input seismic waveform. This is a crucial step in seismology where seismic waves are used for probing the earth. Impedance forms an important step in the interpretation of the earth's properties. Conventionally, impedance is inverted from the seismic data using some approximations. In my workflow, I use machine learning to allow machines to learn the inversion workflow by training it using synthetic dataset. The synthetic dataset has been generated using Geostatistical techniques and Markov Chain Monte Carlo process along with full waveform seismic forward modeling. The current data is considering 1D wave propagation, that can be considered similar to well logs.
#
# The current architecture of the neural network consists of two 1D convolutional neural network layers with a Rectified Linear Unit at the end of each 1D CNN. The loss function for the training case is defined as the mean square error loss. I have used PyTorch for setting up the neural network and for training the network. 520 samples are used as training data. The training is performed for 1000 iterations. The network architecture and the hyperparameters were chosen based on trial and error method. This is still a work in progress. I am only presenting a preliminary implementation.
#
# The execution of the code assumes that CUDA version of pytorch is already installed. After training the network, it has been used to predict impedance using test dataset that was not used for the training process. The test results seemed promising. As part of the future work, the network will be made deeper to capture for more subtle changes in the impedance output for the test results. The results of the neural network depends heavily on the hyperpaprameters. A slight change in some of the hyperparameters impacted the results heavily. I plan to do an exhaustive hyperparameter search to deduce the perfect set of hyperparameters suitable for the model. As an extension, the network will be test on a real well data to evaluate the performance for real business cases. The final goal of the project is to extend the 1D version to 2D/ 3D data and even 4D seismic that is becoming popular in the current time especially for reservoir surveillance purposes.

# %%
# All pre-requisites for running the codes. Assumes that CUDA version of pytorch is installed
import seaborn as sns
import torch 
import torch.nn as nn
import torch.autograd 
from torch.autograd import Variable
import scipy.io as sio
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import numpy as np
from random import randint
import torch.nn.functional as F
from scipy.interpolate import UnivariateSpline

# %%
# Function to convert reflectivity series to impedance values
def rcs2imp(rcs,znot):
    ircs = np.zeros(rcs.size)
    n = rcs.size
    # rcs2 = (rcs[1:n]+rcs[0:n-1])/2.
    ircs=np.cumsum(rcs)
    imp=znot*np.exp(2*ircs)  
    
    return imp

# %%
# Loading the Training data 
# and separating into training and test set
dataframe = sio.loadmat('Train_DataSyn_Ricker30.mat')

#make sure not to take too many traces
howMany = 2020 # Seismic data considered out of 10000 data points 
np.random.seed(9) # For replication of results
indxRand = [randint(0,dataframe['wz_with_multiples'].shape[1]-1) for p in range(0,howMany)]

# Seismic traces
TrainingSeismic = dataframe['wz_with_multiples']
TrainingSeismic = TrainingSeismic.transpose()
TrainingSeismic = TrainingSeismic[indxRand,:]

# Impedance
TrainingImpedance = dataframe['IpTimeVec']/1e6
TrainingImpedance = TrainingImpedance.transpose()
TrainingImpedance = TrainingImpedance[indxRand,:]

# Testing--> Not Trained on Data
dataframe = sio.loadmat('HardTest_DataSyn_Ricker30.mat')

TestingSeismic = dataframe['wz_with_multiples']
TestingSeismic = TestingSeismic.transpose()[:, 0:333]

TestingImpedance = dataframe['IpTimeVec']/1e6
TestingImpedance = TestingImpedance.transpose()[:, 0:333]

print(TestingImpedance.shape[1])


dt = 4.3875e-4
time = np.linspace(0,(TrainingSeismic.shape[1]-1)*dt,TrainingSeismic.shape[1])
# Out:
# 331

# %%
sampleNumber = 10

datasetSeismicTrace = TestingSeismic[sampleNumber,:]
print(datasetSeismicTrace.shape)
datasetIpTrace = TestingImpedance[sampleNumber,:]
print(datasetIpTrace.shape)
print(time.shape)
# Out:
# (331,)
# (331,)
# (331,)

# %%
# Make one graph showing sample Training Data
sampleNumbers = np.array([2,54,123,209])

fig, axs = plt.subplots(1, 4, sharey=True)
axs[0].invert_yaxis()
fig.suptitle('Various Examples of Training and Set Aside Data (SameVariogramRanges)', y=1.08)

# Seismic traces
for i in range(4):
    sampleNumber = sampleNumbers[i];
    datasetSeismicTrace = TrainingSeismic[sampleNumber,:]
    datasetIpTrace = TrainingImpedance[sampleNumber,:]
    
    line1, = axs[i].plot(datasetSeismicTrace, time, 'r-')
    axs[i].set_xlabel('Amplitude', color='r')
    axs[i].tick_params('x', colors='r')
    ax2 = axs[i].twiny()
    line2, = ax2.plot(datasetIpTrace, time, 'b-')
    ax2.set_xlabel('Impedance', color='b')
    ax2.tick_params('x', colors='b')
lgd = plt.legend((line1, line2), ('Seismic', 'Impedance'), bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.savefig('Figures/ExamplesOfTrainingSets.png', bbox_extra_artists=(lgd,), bbox_inches='tight') 

# Make one graph showing sample Training Data
sampleNumbers = np.array([2,54,123,209])

fig, axs = plt.subplots(1, 4, sharey=True)
axs[0].invert_yaxis()
fig.suptitle('Various Examples of Testing Data (Different Variogram Ranges Than Test)', y=1.08)

# Seismic traces
for i in range(4):
    sampleNumber = sampleNumbers[i];
    datasetSeismicTrace = TestingSeismic[sampleNumber,:]
    datasetIpTrace = TestingImpedance[sampleNumber,:]
    
    line1, = axs[i].plot(datasetSeismicTrace, time, 'r-')
    axs[i].set_xlabel('Amplitude', color='r')
    axs[i].tick_params('x', colors='r')
    ax2 = axs[i].twiny()
    line2, = ax2.plot(datasetIpTrace, time, 'b-')
    ax2.set_xlabel('Impedance', color='b')
    ax2.tick_params('x', colors='b')
lgd = plt.legend((line1, line2), ('Seismic', 'Impedance'), bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# fig.savefig('Figures/ExamplesOfTestingSets.png', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
# Separating the selected traces into training and test sets
# Preprocessing of data before using in the network

#validation 500
#testing 1000
#training 520?

howManyToValidate = 500
howManyToTest = 1000 
fromWhich = 0 # Based on maximum of the source wavelet
tillWhich = TrainingSeismic.shape[1] # Based on last sample before interpolation of impedance and reflection coefficients

valX = (TrainingSeismic[:howManyToValidate,fromWhich:tillWhich]) 
testX = (TrainingSeismic[howManyToValidate:howManyToValidate+howManyToTest,fromWhich:tillWhich])
trainX = (TrainingSeismic[howManyToValidate+howManyToTest:,fromWhich:tillWhich])

valX = torch.FloatTensor(np.reshape(valX, (valX.shape[0], 1, valX.shape[1])))
testX = torch.FloatTensor(np.reshape(testX, (testX.shape[0], 1, testX.shape[1])))
trainX = torch.FloatTensor(np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1])))

valIp = (TrainingImpedance[:howManyToValidate,0:-fromWhich+tillWhich])
testIp = (TrainingImpedance[howManyToValidate:howManyToValidate+howManyToTest,0:-fromWhich+tillWhich])
trainIp = (TrainingImpedance[howManyToValidate+howManyToTest:,0:-fromWhich+tillWhich])

valIp = torch.FloatTensor(np.reshape(valIp, (valIp.shape[0], 1, valIp.shape[1])))
testIp = torch.FloatTensor(np.reshape(testIp, (testIp.shape[0], 1, testIp.shape[1])))
trainIp = torch.FloatTensor(np.reshape(trainIp, (trainIp.shape[0], 1, trainIp.shape[1])))


signalLength = trainX.shape[0]

# Plotting the data after preprocessing. This is used as input for the training as well as test
fig = plt.figure()
sampleNumber = 10;

np.linspace(2.0, 3.0, num=5)
fig, ax1 = plt.subplots()
ax1.plot(time, trainX[sampleNumber,0,:].numpy(), 'b-')
ax1.set_xlabel('time (s)')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Seismic Amplitude', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(time, trainIp[sampleNumber,0,:].numpy(), 'r-')
ax2.set_ylabel('Impedance', color='r')
ax2.tick_params('y', colors='r')

fig.tight_layout()
plt.show()
fig.savefig('Figures/InputVsOutput.png')

# %%
np.min(trainX.numpy())
# Out:
# -0.23854081

# %%
# Hyperparameters for the CNN
num_epochs = 500
batch_size = 1
learning_rate = 0.001

noOfNeurons = 60
dilation = 1
kernel_size = 300
stride = 1
padding = int(((dilation*(kernel_size-1)-1)/stride-1)/2)
print("Padding size {}".format(padding))

class rcs2impcnn(nn.Module):
    def __init__(self):
        super(rcs2impcnn, self).__init__()

    def forward(self, x, ipp):
        return ipp*torch.exp(2*torch.cumsum(x,2)).cuda()

# CNN Model (2 conv layer)
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.layer1 = nn.Sequential(
            # input, output, kernel, stride  ...  kernel_size<stride+traces.shape[2]
#            Lin+2∗padding−dilation∗(kernel_size−1)−1)/stride+1
            nn.Conv1d(1, noOfNeurons, kernel_size=kernel_size, stride=1, padding = padding+1),
            nn.ReLU())

        self.layer2 = nn.Sequential(
            nn.Conv1d(noOfNeurons, 1, kernel_size=kernel_size, stride=1, padding = padding+2),
            nn.ReLU())
#         self.layer1 = nn.Sequential(
#             # input, output, kernel, stride  ...  kernel_size<stride+traces.shape[2]
# #            Lin+2∗padding−dilation∗(kernel_size−1)−1)/stride+1
#             nn.Conv1d(1, noOfNeurons, kernel_size=kernel_size, stride=1, padding = padding+1),
#             nn.ReLU(),
#             nn.Conv1d(noOfNeurons, 1, kernel_size=kernel_size, stride=1, padding = padding+2),
#             nn.Tanh())
#         self.rcs2imp = rcs2impcnn()

    

    def forward(self, x):
        out = self.layer1(x)
        # out = F.tanh(self.layer2(out))
        out = self.layer2(out)
        # out = out.view(out.size(0), -1)

#         ipp = ipp.repeat(1,1,out.size()[2])
#         ipp = ipp.permute(1, 0, 2)
#         out = self.rcs2imp(out,ipp)

        
#        out = self.fc(out)

        return out

cnn = CNN()
cnn.cuda()
# Out:
# Padding size 148
# CNN (
#   (layer1): Sequential (
#     (0): Conv1d(1, 60, kernel_size=(300,), stride=(1,), padding=(149,))
#     (1): ReLU ()
#   )
#   (layer2): Sequential (
#     (0): Conv1d(60, 1, kernel_size=(300,), stride=(1,), padding=(150,))
#     (1): ReLU ()
#   )
# )

# %%
# Training the model

# Loss and Optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate)

batch_size_tot = trainX.shape[0]
no_of_batches = (batch_size_tot - batch_size_tot%batch_size)/batch_size
no_of_batches = int(no_of_batches)

trainLosses = []   
valLosses = [] 

# Train the Model
for epoch in range(num_epochs):
        for ii in range(no_of_batches):
#            optimizer.zero_grad()
#            traces = Variable(trainX[ii*batch_size:(ii+1)*batch_size,:,:]).cuda()  
            # First value of Ip used if the loss criteria is impedance instead of reflection coefficients
            ipp = Variable(trainIp[ii*batch_size:(ii+1)*batch_size,:,0]).cuda()  
#            outputs = cnn(traces,ipp)
#            
#            outputs = outputs.view(batch_size, 1, outputs.size()[1])
#            yy = Variable(trainIp[ii*batch_size:(ii+1)*batch_size,:,:]).cuda();

            
            traces = Variable(trainX[ii*batch_size:(ii+1)*batch_size,:,:]).cuda()
        

            outputs = cnn(traces)
            
#            refl_train = Variable(trainY[ii*batch_size:(ii+1)*batch_size,:,:]).cuda()
            ipyy = Variable(trainIp[ii*batch_size:(ii+1)*batch_size,:,:]).cuda()
            
#             plt.plot(traces.data.cpu().numpy()[0,0,:], '-k')
#             plt.pause(0.05)

            loss = criterion(outputs, ipyy)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
        trainLosses.append(loss.data[0])
        # Validation losses not calculated in this implementation
        valLosses.append(1)    
        print ('Epoch [%d/%d], Iter [%d], Train Loss: %.6f, Validation Loss: %.6f' 
                   %(epoch+1, num_epochs, ii+1, loss.data[0], valLosses[0]))
        
del traces
del outputs
# Out:
# Epoch [1/500], Iter [520], Train Loss: 0.623198, Validation Loss: 1.000000
# Epoch [2/500], Iter [520], Train Loss: 0.643853, Validation Loss: 1.000000
# Epoch [3/500], Iter [520], Train Loss: 0.624140, Validation Loss: 1.000000
# Epoch [4/500], Iter [520], Train Loss: 0.583610, Validation Loss: 1.000000
# Epoch [5/500], Iter [520], Train Loss: 0.564036, Validation Loss: 1.000000
# Epoch [6/500], Iter [520], Train Loss: 0.568852, Validation Loss: 1.000000
# Epoch [7/500], Iter [520], Train Loss: 0.544001, Validation Loss: 1.000000
# Epoch [8/500], Iter [520], Train Loss: 0.525058, Validation Loss: 1.000000
# Epoch [9/500], Iter [520], Train Loss: 0.518216, Validation Loss: 1.000000
# Epoch [10/500], Iter [520], Train Loss: 0.526222, Validation Loss: 1.000000
# Epoch [11/500], Iter [520], Train Loss: 0.529916, Validation Loss: 1.000000
# Epoch [12/500], Iter [520], Train Loss: 0.523982, Validation Loss: 1.000000
# Epoch [13/500], Iter [520], Train Loss: 0.481314, Validation Loss: 1.000000
# Epoch [14/500], Iter [520], Train Loss: 0.462481, Validation Loss: 1.000000
# Epoch [15/500], Iter [520], Train Loss: 0.484625, Validation Loss: 1.000000
# Epoch [16/500], Iter [520], Train Loss: 0.467850, Validation Loss: 1.000000
# Epoch [17/500], Iter [520], Train Loss: 0.485993, Validation Loss: 1.000000
# Epoch [18/500], Iter [520], Train Loss: 0.495406, Validation Loss: 1.000000
# Epoch [19/500], Iter [520], Train Loss: 0.485258, Validation Loss: 1.000000
# Epoch [20/500], Iter [520], Train Loss: 0.491489, Validation Loss: 1.000000
# Epoch [21/500], Iter [520], Train Loss: 0.481058, Validation Loss: 1.000000
# Epoch [22/500], Iter [520], Train Loss: 0.462125, Validation Loss: 1.000000
# Epoch [23/500], Iter [520], Train Loss: 0.473756, Validation Loss: 1.000000
# Epoch [24/500], Iter [520], Train Loss: 0.476768, Validation Loss: 1.000000
# Epoch [25/500], Iter [520], Train Loss: 0.487631, Validation Loss: 1.000000
# Epoch [26/500], Iter [520], Train Loss: 0.487948, Validation Loss: 1.000000
# Epoch [27/500], Iter [520], Train Loss: 0.471470, Validation Loss: 1.000000
# Epoch [28/500], Iter [520], Train Loss: 0.452381, Validation Loss: 1.000000
# Epoch [29/500], Iter [520], Train Loss: 0.481030, Validation Loss: 1.000000
# Epoch [30/500], Iter [520], Train Loss: 0.472667, Validation Loss: 1.000000
# Epoch [31/500], Iter [520], Train Loss: 0.484254, Validation Loss: 1.000000
# Epoch [32/500], Iter [520], Train Loss: 0.493841, Validation Loss: 1.000000
# Epoch [33/500], Iter [520], Train Loss: 0.504172, Validation Loss: 1.000000
# Epoch [34/500], Iter [520], Train Loss: 0.464767, Validation Loss: 1.000000
# Epoch [35/500], Iter [520], Train Loss: 0.453081, Validation Loss: 1.000000
# Epoch [36/500], Iter [520], Train Loss: 0.463696, Validation Loss: 1.000000
# Epoch [37/500], Iter [520], Train Loss: 0.480352, Validation Loss: 1.000000
# Epoch [38/500], Iter [520], Train Loss: 0.421235, Validation Loss: 1.000000
# Epoch [39/500], Iter [520], Train Loss: 0.453284, Validation Loss: 1.000000
# Epoch [40/500], Iter [520], Train Loss: 0.433220, Validation Loss: 1.000000
# Epoch [41/500], Iter [520], Train Loss: 0.462366, Validation Loss: 1.000000
# Epoch [42/500], Iter [520], Train Loss: 0.441636, Validation Loss: 1.000000
# Epoch [43/500], Iter [520], Train Loss: 0.433170, Validation Loss: 1.000000
# Epoch [44/500], Iter [520], Train Loss: 0.419617, Validation Loss: 1.000000
# Epoch [45/500], Iter [520], Train Loss: 0.444853, Validation Loss: 1.000000
# Epoch [46/500], Iter [520], Train Loss: 0.459776, Validation Loss: 1.000000
# Epoch [47/500], Iter [520], Train Loss: 0.446603, Validation Loss: 1.000000
# Epoch [48/500], Iter [520], Train Loss: 0.450571, Validation Loss: 1.000000
# Epoch [49/500], Iter [520], Train Loss: 0.493792, Validation Loss: 1.000000
# Epoch [50/500], Iter [520], Train Loss: 0.483839, Validation Loss: 1.000000
# Epoch [51/500], Iter [520], Train Loss: 0.477780, Validation Loss: 1.000000
# Epoch [52/500], Iter [520], Train Loss: 0.512176, Validation Loss: 1.000000
# Epoch [53/500], Iter [520], Train Loss: 0.539435, Validation Loss: 1.000000
# Epoch [54/500], Iter [520], Train Loss: 0.533576, Validation Loss: 1.000000
# Epoch [55/500], Iter [520], Train Loss: 0.549559, Validation Loss: 1.000000
# Epoch [56/500], Iter [520], Train Loss: 0.549470, Validation Loss: 1.000000
# Epoch [57/500], Iter [520], Train Loss: 0.516066, Validation Loss: 1.000000
# Epoch [58/500], Iter [520], Train Loss: 0.599222, Validation Loss: 1.000000
# Epoch [59/500], Iter [520], Train Loss: 0.455384, Validation Loss: 1.000000
# Epoch [60/500], Iter [520], Train Loss: 0.508552, Validation Loss: 1.000000
# Epoch [61/500], Iter [520], Train Loss: 0.493307, Validation Loss: 1.000000
# Epoch [62/500], Iter [520], Train Loss: 0.509405, Validation Loss: 1.000000
# Epoch [63/500], Iter [520], Train Loss: 0.501183, Validation Loss: 1.000000
# Epoch [64/500], Iter [520], Train Loss: 0.491851, Validation Loss: 1.000000
# Epoch [65/500], Iter [520], Train Loss: 0.450652, Validation Loss: 1.000000
# Epoch [66/500], Iter [520], Train Loss: 0.474741, Validation Loss: 1.000000
# Epoch [67/500], Iter [520], Train Loss: 0.441282, Validation Loss: 1.000000
# Epoch [68/500], Iter [520], Train Loss: 0.379348, Validation Loss: 1.000000
# Epoch [69/500], Iter [520], Train Loss: 0.422304, Validation Loss: 1.000000
# Epoch [70/500], Iter [520], Train Loss: 0.412130, Validation Loss: 1.000000
# Epoch [71/500], Iter [520], Train Loss: 0.450771, Validation Loss: 1.000000
# Epoch [72/500], Iter [520], Train Loss: 0.409060, Validation Loss: 1.000000
# Epoch [73/500], Iter [520], Train Loss: 0.437275, Validation Loss: 1.000000
# Epoch [74/500], Iter [520], Train Loss: 0.399637, Validation Loss: 1.000000
# Epoch [75/500], Iter [520], Train Loss: 0.385057, Validation Loss: 1.000000
# Epoch [76/500], Iter [520], Train Loss: 0.391772, Validation Loss: 1.000000
# Epoch [77/500], Iter [520], Train Loss: 0.386895, Validation Loss: 1.000000
# Epoch [78/500], Iter [520], Train Loss: 0.423575, Validation Loss: 1.000000
# Epoch [79/500], Iter [520], Train Loss: 0.358682, Validation Loss: 1.000000
# Epoch [80/500], Iter [520], Train Loss: 0.406488, Validation Loss: 1.000000
# Epoch [81/500], Iter [520], Train Loss: 0.394172, Validation Loss: 1.000000
# Epoch [82/500], Iter [520], Train Loss: 0.419214, Validation Loss: 1.000000
# Epoch [83/500], Iter [520], Train Loss: 0.362079, Validation Loss: 1.000000
# Epoch [84/500], Iter [520], Train Loss: 0.404738, Validation Loss: 1.000000
# Epoch [85/500], Iter [520], Train Loss: 0.452705, Validation Loss: 1.000000
# Epoch [86/500], Iter [520], Train Loss: 0.466459, Validation Loss: 1.000000
# Epoch [87/500], Iter [520], Train Loss: 0.383937, Validation Loss: 1.000000
# Epoch [88/500], Iter [520], Train Loss: 0.465224, Validation Loss: 1.000000
# Epoch [89/500], Iter [520], Train Loss: 0.447743, Validation Loss: 1.000000
# Epoch [90/500], Iter [520], Train Loss: 0.485044, Validation Loss: 1.000000
# Epoch [91/500], Iter [520], Train Loss: 0.422407, Validation Loss: 1.000000
# Epoch [92/500], Iter [520], Train Loss: 0.425758, Validation Loss: 1.000000
# Epoch [93/500], Iter [520], Train Loss: 0.415206, Validation Loss: 1.000000
# Epoch [94/500], Iter [520], Train Loss: 0.398795, Validation Loss: 1.000000
# Epoch [95/500], Iter [520], Train Loss: 0.412445, Validation Loss: 1.000000
# Epoch [96/500], Iter [520], Train Loss: 0.363251, Validation Loss: 1.000000
# Epoch [97/500], Iter [520], Train Loss: 0.426689, Validation Loss: 1.000000
# Epoch [98/500], Iter [520], Train Loss: 0.336346, Validation Loss: 1.000000
# Epoch [99/500], Iter [520], Train Loss: 0.410478, Validation Loss: 1.000000
# Epoch [100/500], Iter [520], Train Loss: 0.340826, Validation Loss: 1.000000
# Epoch [101/500], Iter [520], Train Loss: 0.348077, Validation Loss: 1.000000
# Epoch [102/500], Iter [520], Train Loss: 0.319592, Validation Loss: 1.000000
# Epoch [103/500], Iter [520], Train Loss: 0.350506, Validation Loss: 1.000000
# Epoch [104/500], Iter [520], Train Loss: 0.333889, Validation Loss: 1.000000
# Epoch [105/500], Iter [520], Train Loss: 0.341526, Validation Loss: 1.000000
# Epoch [106/500], Iter [520], Train Loss: 0.337893, Validation Loss: 1.000000
# Epoch [107/500], Iter [520], Train Loss: 0.338431, Validation Loss: 1.000000
# Epoch [108/500], Iter [520], Train Loss: 0.332022, Validation Loss: 1.000000
# Epoch [109/500], Iter [520], Train Loss: 0.357966, Validation Loss: 1.000000
# Epoch [110/500], Iter [520], Train Loss: 0.310061, Validation Loss: 1.000000
# Epoch [111/500], Iter [520], Train Loss: 0.346292, Validation Loss: 1.000000
# Epoch [112/500], Iter [520], Train Loss: 0.322150, Validation Loss: 1.000000
# Epoch [113/500], Iter [520], Train Loss: 0.329339, Validation Loss: 1.000000
# Epoch [114/500], Iter [520], Train Loss: 0.328725, Validation Loss: 1.000000
# Epoch [115/500], Iter [520], Train Loss: 0.324994, Validation Loss: 1.000000
# Epoch [116/500], Iter [520], Train Loss: 0.324382, Validation Loss: 1.000000
# Epoch [117/500], Iter [520], Train Loss: 0.342519, Validation Loss: 1.000000
# Epoch [118/500], Iter [520], Train Loss: 0.331690, Validation Loss: 1.000000
# Epoch [119/500], Iter [520], Train Loss: 0.327987, Validation Loss: 1.000000
# Epoch [120/500], Iter [520], Train Loss: 0.319503, Validation Loss: 1.000000
# Epoch [121/500], Iter [520], Train Loss: 0.321414, Validation Loss: 1.000000
# Epoch [122/500], Iter [520], Train Loss: 0.337953, Validation Loss: 1.000000
# Epoch [123/500], Iter [520], Train Loss: 0.337468, Validation Loss: 1.000000
# Epoch [124/500], Iter [520], Train Loss: 0.317861, Validation Loss: 1.000000
# Epoch [125/500], Iter [520], Train Loss: 0.328099, Validation Loss: 1.000000
# Epoch [126/500], Iter [520], Train Loss: 0.316129, Validation Loss: 1.000000
# Epoch [127/500], Iter [520], Train Loss: 0.380399, Validation Loss: 1.000000
# Epoch [128/500], Iter [520], Train Loss: 0.388318, Validation Loss: 1.000000
# Epoch [129/500], Iter [520], Train Loss: 0.379916, Validation Loss: 1.000000
# Epoch [130/500], Iter [520], Train Loss: 0.314495, Validation Loss: 1.000000
# Epoch [131/500], Iter [520], Train Loss: 0.319148, Validation Loss: 1.000000
# Epoch [132/500], Iter [520], Train Loss: 0.349509, Validation Loss: 1.000000
# Epoch [133/500], Iter [520], Train Loss: 0.343143, Validation Loss: 1.000000
# Epoch [134/500], Iter [520], Train Loss: 0.376675, Validation Loss: 1.000000
# Epoch [135/500], Iter [520], Train Loss: 0.331921, Validation Loss: 1.000000
# Epoch [136/500], Iter [520], Train Loss: 0.322935, Validation Loss: 1.000000
# Epoch [137/500], Iter [520], Train Loss: 0.288454, Validation Loss: 1.000000
# Epoch [138/500], Iter [520], Train Loss: 0.350200, Validation Loss: 1.000000
# Epoch [139/500], Iter [520], Train Loss: 0.282800, Validation Loss: 1.000000
# Epoch [140/500], Iter [520], Train Loss: 0.357225, Validation Loss: 1.000000
# Epoch [141/500], Iter [520], Train Loss: 0.328980, Validation Loss: 1.000000
# Epoch [142/500], Iter [520], Train Loss: 0.297333, Validation Loss: 1.000000
# Epoch [143/500], Iter [520], Train Loss: 0.305559, Validation Loss: 1.000000
# Epoch [144/500], Iter [520], Train Loss: 0.295313, Validation Loss: 1.000000
# Epoch [145/500], Iter [520], Train Loss: 0.337135, Validation Loss: 1.000000
# Epoch [146/500], Iter [520], Train Loss: 0.293260, Validation Loss: 1.000000
# Epoch [147/500], Iter [520], Train Loss: 0.320538, Validation Loss: 1.000000
# Epoch [148/500], Iter [520], Train Loss: 0.453249, Validation Loss: 1.000000
# Epoch [149/500], Iter [520], Train Loss: 0.263382, Validation Loss: 1.000000
# Epoch [150/500], Iter [520], Train Loss: 0.282529, Validation Loss: 1.000000
# Epoch [151/500], Iter [520], Train Loss: 0.304286, Validation Loss: 1.000000
# Epoch [152/500], Iter [520], Train Loss: 0.284338, Validation Loss: 1.000000
# Epoch [153/500], Iter [520], Train Loss: 0.370278, Validation Loss: 1.000000
# Epoch [154/500], Iter [520], Train Loss: 0.276309, Validation Loss: 1.000000
# Epoch [155/500], Iter [520], Train Loss: 0.328544, Validation Loss: 1.000000
# Epoch [156/500], Iter [520], Train Loss: 0.309414, Validation Loss: 1.000000
# Epoch [157/500], Iter [520], Train Loss: 0.250923, Validation Loss: 1.000000
# Epoch [158/500], Iter [520], Train Loss: 0.361524, Validation Loss: 1.000000
# Epoch [159/500], Iter [520], Train Loss: 0.278865, Validation Loss: 1.000000
# Epoch [160/500], Iter [520], Train Loss: 0.292384, Validation Loss: 1.000000
# Epoch [161/500], Iter [520], Train Loss: 0.295958, Validation Loss: 1.000000
# Epoch [162/500], Iter [520], Train Loss: 0.290523, Validation Loss: 1.000000
# Epoch [163/500], Iter [520], Train Loss: 0.268034, Validation Loss: 1.000000
# Epoch [164/500], Iter [520], Train Loss: 0.256042, Validation Loss: 1.000000
# Epoch [165/500], Iter [520], Train Loss: 0.287081, Validation Loss: 1.000000
# Epoch [166/500], Iter [520], Train Loss: 0.278544, Validation Loss: 1.000000
# Epoch [167/500], Iter [520], Train Loss: 0.312662, Validation Loss: 1.000000
# Epoch [168/500], Iter [520], Train Loss: 0.291829, Validation Loss: 1.000000
# Epoch [169/500], Iter [520], Train Loss: 0.293503, Validation Loss: 1.000000
# Epoch [170/500], Iter [520], Train Loss: 0.273228, Validation Loss: 1.000000
# Epoch [171/500], Iter [520], Train Loss: 0.246125, Validation Loss: 1.000000
# Epoch [172/500], Iter [520], Train Loss: 0.330282, Validation Loss: 1.000000
# Epoch [173/500], Iter [520], Train Loss: 0.247081, Validation Loss: 1.000000
# Epoch [174/500], Iter [520], Train Loss: 0.300785, Validation Loss: 1.000000
# Epoch [175/500], Iter [520], Train Loss: 0.275281, Validation Loss: 1.000000
# Epoch [176/500], Iter [520], Train Loss: 0.273251, Validation Loss: 1.000000
# Epoch [177/500], Iter [520], Train Loss: 0.238970, Validation Loss: 1.000000
# Epoch [178/500], Iter [520], Train Loss: 0.285110, Validation Loss: 1.000000
# Epoch [179/500], Iter [520], Train Loss: 0.258474, Validation Loss: 1.000000
# Epoch [180/500], Iter [520], Train Loss: 0.254130, Validation Loss: 1.000000
# Epoch [181/500], Iter [520], Train Loss: 0.296762, Validation Loss: 1.000000
# Epoch [182/500], Iter [520], Train Loss: 0.228006, Validation Loss: 1.000000
# Epoch [183/500], Iter [520], Train Loss: 0.289624, Validation Loss: 1.000000
# Epoch [184/500], Iter [520], Train Loss: 0.272188, Validation Loss: 1.000000
# Epoch [185/500], Iter [520], Train Loss: 0.236314, Validation Loss: 1.000000
# Epoch [186/500], Iter [520], Train Loss: 0.227922, Validation Loss: 1.000000
# Epoch [187/500], Iter [520], Train Loss: 0.316363, Validation Loss: 1.000000
# Epoch [188/500], Iter [520], Train Loss: 0.224630, Validation Loss: 1.000000
# Epoch [189/500], Iter [520], Train Loss: 0.265154, Validation Loss: 1.000000
# Epoch [190/500], Iter [520], Train Loss: 0.247339, Validation Loss: 1.000000
# Epoch [191/500], Iter [520], Train Loss: 0.325258, Validation Loss: 1.000000
# Epoch [192/500], Iter [520], Train Loss: 0.223490, Validation Loss: 1.000000
# Epoch [193/500], Iter [520], Train Loss: 0.226498, Validation Loss: 1.000000
# Epoch [194/500], Iter [520], Train Loss: 0.288351, Validation Loss: 1.000000
# Epoch [195/500], Iter [520], Train Loss: 0.242708, Validation Loss: 1.000000
# Epoch [196/500], Iter [520], Train Loss: 0.250844, Validation Loss: 1.000000
# Epoch [197/500], Iter [520], Train Loss: 0.318981, Validation Loss: 1.000000
# Epoch [198/500], Iter [520], Train Loss: 0.222859, Validation Loss: 1.000000
# Epoch [199/500], Iter [520], Train Loss: 0.239207, Validation Loss: 1.000000
# Epoch [200/500], Iter [520], Train Loss: 0.270265, Validation Loss: 1.000000
# Epoch [201/500], Iter [520], Train Loss: 0.207072, Validation Loss: 1.000000
# Epoch [202/500], Iter [520], Train Loss: 0.285417, Validation Loss: 1.000000
# Epoch [203/500], Iter [520], Train Loss: 0.224501, Validation Loss: 1.000000
# Epoch [204/500], Iter [520], Train Loss: 0.235714, Validation Loss: 1.000000
# Epoch [205/500], Iter [520], Train Loss: 0.208065, Validation Loss: 1.000000
# Epoch [206/500], Iter [520], Train Loss: 0.272146, Validation Loss: 1.000000
# Epoch [207/500], Iter [520], Train Loss: 0.204961, Validation Loss: 1.000000
# Epoch [208/500], Iter [520], Train Loss: 0.230173, Validation Loss: 1.000000
# Epoch [209/500], Iter [520], Train Loss: 0.251726, Validation Loss: 1.000000
# Epoch [210/500], Iter [520], Train Loss: 0.258263, Validation Loss: 1.000000
# Epoch [211/500], Iter [520], Train Loss: 0.210459, Validation Loss: 1.000000
# Epoch [212/500], Iter [520], Train Loss: 0.231298, Validation Loss: 1.000000
# Epoch [213/500], Iter [520], Train Loss: 0.334557, Validation Loss: 1.000000
# Epoch [214/500], Iter [520], Train Loss: 0.240312, Validation Loss: 1.000000
# Epoch [215/500], Iter [520], Train Loss: 0.243575, Validation Loss: 1.000000
# Epoch [216/500], Iter [520], Train Loss: 0.245543, Validation Loss: 1.000000
# Epoch [217/500], Iter [520], Train Loss: 0.235331, Validation Loss: 1.000000
# Epoch [218/500], Iter [520], Train Loss: 0.203531, Validation Loss: 1.000000
# Epoch [219/500], Iter [520], Train Loss: 0.350148, Validation Loss: 1.000000
# Epoch [220/500], Iter [520], Train Loss: 0.207955, Validation Loss: 1.000000
# Epoch [221/500], Iter [520], Train Loss: 0.231651, Validation Loss: 1.000000
# Epoch [222/500], Iter [520], Train Loss: 0.214350, Validation Loss: 1.000000
# Epoch [223/500], Iter [520], Train Loss: 0.218486, Validation Loss: 1.000000
# Epoch [224/500], Iter [520], Train Loss: 0.190906, Validation Loss: 1.000000
# Epoch [225/500], Iter [520], Train Loss: 0.232489, Validation Loss: 1.000000
# Epoch [226/500], Iter [520], Train Loss: 0.264445, Validation Loss: 1.000000
# Epoch [227/500], Iter [520], Train Loss: 0.193677, Validation Loss: 1.000000
# Epoch [228/500], Iter [520], Train Loss: 0.219450, Validation Loss: 1.000000
# Epoch [229/500], Iter [520], Train Loss: 0.318375, Validation Loss: 1.000000
# Epoch [230/500], Iter [520], Train Loss: 0.196956, Validation Loss: 1.000000
# Epoch [231/500], Iter [520], Train Loss: 0.305790, Validation Loss: 1.000000
# Epoch [232/500], Iter [520], Train Loss: 0.198125, Validation Loss: 1.000000
# Epoch [233/500], Iter [520], Train Loss: 0.197739, Validation Loss: 1.000000
# Epoch [234/500], Iter [520], Train Loss: 0.225292, Validation Loss: 1.000000
# Epoch [235/500], Iter [520], Train Loss: 0.232548, Validation Loss: 1.000000
# Epoch [236/500], Iter [520], Train Loss: 0.188691, Validation Loss: 1.000000
# Epoch [237/500], Iter [520], Train Loss: 0.220651, Validation Loss: 1.000000
# Epoch [238/500], Iter [520], Train Loss: 0.192310, Validation Loss: 1.000000
# Epoch [239/500], Iter [520], Train Loss: 0.208604, Validation Loss: 1.000000
# Epoch [240/500], Iter [520], Train Loss: 0.221327, Validation Loss: 1.000000
# Epoch [241/500], Iter [520], Train Loss: 0.213210, Validation Loss: 1.000000
# Epoch [242/500], Iter [520], Train Loss: 0.201577, Validation Loss: 1.000000
# Epoch [243/500], Iter [520], Train Loss: 0.243757, Validation Loss: 1.000000
# Epoch [244/500], Iter [520], Train Loss: 0.181792, Validation Loss: 1.000000
# Epoch [245/500], Iter [520], Train Loss: 0.230212, Validation Loss: 1.000000
# Epoch [246/500], Iter [520], Train Loss: 0.200083, Validation Loss: 1.000000
# Epoch [247/500], Iter [520], Train Loss: 0.199648, Validation Loss: 1.000000
# Epoch [248/500], Iter [520], Train Loss: 0.220117, Validation Loss: 1.000000
# Epoch [249/500], Iter [520], Train Loss: 0.228513, Validation Loss: 1.000000
# Epoch [250/500], Iter [520], Train Loss: 0.306163, Validation Loss: 1.000000
# Epoch [251/500], Iter [520], Train Loss: 0.234012, Validation Loss: 1.000000
# Epoch [252/500], Iter [520], Train Loss: 0.221493, Validation Loss: 1.000000
# Epoch [253/500], Iter [520], Train Loss: 0.235432, Validation Loss: 1.000000
# Epoch [254/500], Iter [520], Train Loss: 0.195241, Validation Loss: 1.000000
# Epoch [255/500], Iter [520], Train Loss: 0.207600, Validation Loss: 1.000000
# Epoch [256/500], Iter [520], Train Loss: 0.251529, Validation Loss: 1.000000
# Epoch [257/500], Iter [520], Train Loss: 0.242800, Validation Loss: 1.000000
# Epoch [258/500], Iter [520], Train Loss: 0.243700, Validation Loss: 1.000000
# Epoch [259/500], Iter [520], Train Loss: 0.197310, Validation Loss: 1.000000
# Epoch [260/500], Iter [520], Train Loss: 0.211032, Validation Loss: 1.000000
# Epoch [261/500], Iter [520], Train Loss: 0.206950, Validation Loss: 1.000000
# Epoch [262/500], Iter [520], Train Loss: 0.193330, Validation Loss: 1.000000
# Epoch [263/500], Iter [520], Train Loss: 0.294856, Validation Loss: 1.000000
# Epoch [264/500], Iter [520], Train Loss: 0.190044, Validation Loss: 1.000000
# Epoch [265/500], Iter [520], Train Loss: 0.271541, Validation Loss: 1.000000
# Epoch [266/500], Iter [520], Train Loss: 0.196266, Validation Loss: 1.000000
# Epoch [267/500], Iter [520], Train Loss: 0.214918, Validation Loss: 1.000000
# Epoch [268/500], Iter [520], Train Loss: 0.244503, Validation Loss: 1.000000
# Epoch [269/500], Iter [520], Train Loss: 0.186127, Validation Loss: 1.000000
# Epoch [270/500], Iter [520], Train Loss: 0.219900, Validation Loss: 1.000000
# Epoch [271/500], Iter [520], Train Loss: 0.218692, Validation Loss: 1.000000
# Epoch [272/500], Iter [520], Train Loss: 0.198052, Validation Loss: 1.000000
# Epoch [273/500], Iter [520], Train Loss: 0.215210, Validation Loss: 1.000000
# Epoch [274/500], Iter [520], Train Loss: 0.244980, Validation Loss: 1.000000
# Epoch [275/500], Iter [520], Train Loss: 0.186167, Validation Loss: 1.000000
# Epoch [276/500], Iter [520], Train Loss: 0.253722, Validation Loss: 1.000000
# Epoch [277/500], Iter [520], Train Loss: 0.195207, Validation Loss: 1.000000
# Epoch [278/500], Iter [520], Train Loss: 0.203912, Validation Loss: 1.000000
# Epoch [279/500], Iter [520], Train Loss: 0.219295, Validation Loss: 1.000000
# Epoch [280/500], Iter [520], Train Loss: 0.183374, Validation Loss: 1.000000
# Epoch [281/500], Iter [520], Train Loss: 0.268580, Validation Loss: 1.000000
# Epoch [282/500], Iter [520], Train Loss: 0.187914, Validation Loss: 1.000000
# Epoch [283/500], Iter [520], Train Loss: 0.215961, Validation Loss: 1.000000
# Epoch [284/500], Iter [520], Train Loss: 0.227193, Validation Loss: 1.000000
# Epoch [285/500], Iter [520], Train Loss: 0.192674, Validation Loss: 1.000000
# Epoch [286/500], Iter [520], Train Loss: 0.298956, Validation Loss: 1.000000
# Epoch [287/500], Iter [520], Train Loss: 0.189480, Validation Loss: 1.000000
# Epoch [288/500], Iter [520], Train Loss: 0.199903, Validation Loss: 1.000000
# Epoch [289/500], Iter [520], Train Loss: 0.199962, Validation Loss: 1.000000
# Epoch [290/500], Iter [520], Train Loss: 0.192326, Validation Loss: 1.000000
# Epoch [291/500], Iter [520], Train Loss: 0.297186, Validation Loss: 1.000000
# Epoch [292/500], Iter [520], Train Loss: 0.185276, Validation Loss: 1.000000
# Epoch [293/500], Iter [520], Train Loss: 0.235122, Validation Loss: 1.000000
# Epoch [294/500], Iter [520], Train Loss: 0.227515, Validation Loss: 1.000000
# Epoch [295/500], Iter [520], Train Loss: 0.172613, Validation Loss: 1.000000
# Epoch [296/500], Iter [520], Train Loss: 0.191020, Validation Loss: 1.000000
# Epoch [297/500], Iter [520], Train Loss: 0.349072, Validation Loss: 1.000000
# Epoch [298/500], Iter [520], Train Loss: 0.222227, Validation Loss: 1.000000
# Epoch [299/500], Iter [520], Train Loss: 0.228577, Validation Loss: 1.000000
# Epoch [300/500], Iter [520], Train Loss: 0.191389, Validation Loss: 1.000000
# Epoch [301/500], Iter [520], Train Loss: 0.214091, Validation Loss: 1.000000
# Epoch [302/500], Iter [520], Train Loss: 0.241760, Validation Loss: 1.000000
# Epoch [303/500], Iter [520], Train Loss: 0.176551, Validation Loss: 1.000000
# Epoch [304/500], Iter [520], Train Loss: 0.229014, Validation Loss: 1.000000
# Epoch [305/500], Iter [520], Train Loss: 0.187007, Validation Loss: 1.000000
# Epoch [306/500], Iter [520], Train Loss: 0.194303, Validation Loss: 1.000000
# Epoch [307/500], Iter [520], Train Loss: 0.225140, Validation Loss: 1.000000
# Epoch [308/500], Iter [520], Train Loss: 0.200195, Validation Loss: 1.000000
# Epoch [309/500], Iter [520], Train Loss: 0.223602, Validation Loss: 1.000000
# Epoch [310/500], Iter [520], Train Loss: 0.204776, Validation Loss: 1.000000
# Epoch [311/500], Iter [520], Train Loss: 0.241968, Validation Loss: 1.000000
# Epoch [312/500], Iter [520], Train Loss: 0.188562, Validation Loss: 1.000000
# Epoch [313/500], Iter [520], Train Loss: 0.191958, Validation Loss: 1.000000
# Epoch [314/500], Iter [520], Train Loss: 0.224819, Validation Loss: 1.000000
# Epoch [315/500], Iter [520], Train Loss: 0.205473, Validation Loss: 1.000000
# Epoch [316/500], Iter [520], Train Loss: 0.370600, Validation Loss: 1.000000
# Epoch [317/500], Iter [520], Train Loss: 0.215916, Validation Loss: 1.000000
# Epoch [318/500], Iter [520], Train Loss: 0.246707, Validation Loss: 1.000000
# Epoch [319/500], Iter [520], Train Loss: 0.222795, Validation Loss: 1.000000
# Epoch [320/500], Iter [520], Train Loss: 0.254947, Validation Loss: 1.000000
# Epoch [321/500], Iter [520], Train Loss: 0.184071, Validation Loss: 1.000000
# Epoch [322/500], Iter [520], Train Loss: 0.205311, Validation Loss: 1.000000
# Epoch [323/500], Iter [520], Train Loss: 0.173302, Validation Loss: 1.000000
# Epoch [324/500], Iter [520], Train Loss: 0.211771, Validation Loss: 1.000000
# Epoch [325/500], Iter [520], Train Loss: 0.216891, Validation Loss: 1.000000
# Epoch [326/500], Iter [520], Train Loss: 0.202863, Validation Loss: 1.000000
# Epoch [327/500], Iter [520], Train Loss: 0.202499, Validation Loss: 1.000000
# Epoch [328/500], Iter [520], Train Loss: 0.180246, Validation Loss: 1.000000
# Epoch [329/500], Iter [520], Train Loss: 0.274185, Validation Loss: 1.000000
# Epoch [330/500], Iter [520], Train Loss: 0.182586, Validation Loss: 1.000000
# Epoch [331/500], Iter [520], Train Loss: 0.287659, Validation Loss: 1.000000
# Epoch [332/500], Iter [520], Train Loss: 0.200162, Validation Loss: 1.000000
# Epoch [333/500], Iter [520], Train Loss: 0.211930, Validation Loss: 1.000000
# Epoch [334/500], Iter [520], Train Loss: 0.246476, Validation Loss: 1.000000
# Epoch [335/500], Iter [520], Train Loss: 0.191715, Validation Loss: 1.000000
# Epoch [336/500], Iter [520], Train Loss: 0.171640, Validation Loss: 1.000000
# Epoch [337/500], Iter [520], Train Loss: 0.222010, Validation Loss: 1.000000
# Epoch [338/500], Iter [520], Train Loss: 0.194153, Validation Loss: 1.000000
# Epoch [339/500], Iter [520], Train Loss: 0.183481, Validation Loss: 1.000000
# Epoch [340/500], Iter [520], Train Loss: 0.242119, Validation Loss: 1.000000
# Epoch [341/500], Iter [520], Train Loss: 0.210072, Validation Loss: 1.000000
# Epoch [342/500], Iter [520], Train Loss: 0.235004, Validation Loss: 1.000000
# Epoch [343/500], Iter [520], Train Loss: 0.174613, Validation Loss: 1.000000
# Epoch [344/500], Iter [520], Train Loss: 0.277112, Validation Loss: 1.000000
# Epoch [345/500], Iter [520], Train Loss: 0.187782, Validation Loss: 1.000000
# Epoch [346/500], Iter [520], Train Loss: 0.191819, Validation Loss: 1.000000
# Epoch [347/500], Iter [520], Train Loss: 0.209456, Validation Loss: 1.000000
# Epoch [348/500], Iter [520], Train Loss: 0.439821, Validation Loss: 1.000000
# Epoch [349/500], Iter [520], Train Loss: 0.316100, Validation Loss: 1.000000
# Epoch [350/500], Iter [520], Train Loss: 0.222337, Validation Loss: 1.000000
# Epoch [351/500], Iter [520], Train Loss: 0.181707, Validation Loss: 1.000000
# Epoch [352/500], Iter [520], Train Loss: 0.242686, Validation Loss: 1.000000
# Epoch [353/500], Iter [520], Train Loss: 0.193182, Validation Loss: 1.000000
# Epoch [354/500], Iter [520], Train Loss: 0.311441, Validation Loss: 1.000000
# Epoch [355/500], Iter [520], Train Loss: 0.258164, Validation Loss: 1.000000
# Epoch [356/500], Iter [520], Train Loss: 0.208065, Validation Loss: 1.000000
# Epoch [357/500], Iter [520], Train Loss: 0.227651, Validation Loss: 1.000000
# Epoch [358/500], Iter [520], Train Loss: 0.536545, Validation Loss: 1.000000
# Epoch [359/500], Iter [520], Train Loss: 0.343124, Validation Loss: 1.000000
# Epoch [360/500], Iter [520], Train Loss: 0.221943, Validation Loss: 1.000000
# Epoch [361/500], Iter [520], Train Loss: 0.192869, Validation Loss: 1.000000
# Epoch [362/500], Iter [520], Train Loss: 0.223482, Validation Loss: 1.000000
# Epoch [363/500], Iter [520], Train Loss: 0.217460, Validation Loss: 1.000000
# Epoch [364/500], Iter [520], Train Loss: 0.282390, Validation Loss: 1.000000
# Epoch [365/500], Iter [520], Train Loss: 0.263930, Validation Loss: 1.000000
# Epoch [366/500], Iter [520], Train Loss: 0.223543, Validation Loss: 1.000000
# Epoch [367/500], Iter [520], Train Loss: 0.189431, Validation Loss: 1.000000
# Epoch [368/500], Iter [520], Train Loss: 0.477487, Validation Loss: 1.000000
# Epoch [369/500], Iter [520], Train Loss: 0.274585, Validation Loss: 1.000000
# Epoch [370/500], Iter [520], Train Loss: 0.190919, Validation Loss: 1.000000
# Epoch [371/500], Iter [520], Train Loss: 0.226233, Validation Loss: 1.000000
# Epoch [372/500], Iter [520], Train Loss: 0.246085, Validation Loss: 1.000000
# Epoch [373/500], Iter [520], Train Loss: 0.183258, Validation Loss: 1.000000
# Epoch [374/500], Iter [520], Train Loss: 0.216581, Validation Loss: 1.000000
# Epoch [375/500], Iter [520], Train Loss: 0.220770, Validation Loss: 1.000000
# Epoch [376/500], Iter [520], Train Loss: 0.448962, Validation Loss: 1.000000
# Epoch [377/500], Iter [520], Train Loss: 0.332569, Validation Loss: 1.000000
# Epoch [378/500], Iter [520], Train Loss: 0.213604, Validation Loss: 1.000000
# Epoch [379/500], Iter [520], Train Loss: 0.181784, Validation Loss: 1.000000
# Epoch [380/500], Iter [520], Train Loss: 0.173482, Validation Loss: 1.000000
# Epoch [381/500], Iter [520], Train Loss: 0.190561, Validation Loss: 1.000000
# Epoch [382/500], Iter [520], Train Loss: 0.321624, Validation Loss: 1.000000
# Epoch [383/500], Iter [520], Train Loss: 0.284493, Validation Loss: 1.000000
# Epoch [384/500], Iter [520], Train Loss: 0.179447, Validation Loss: 1.000000
# Epoch [385/500], Iter [520], Train Loss: 0.175964, Validation Loss: 1.000000
# Epoch [386/500], Iter [520], Train Loss: 0.248691, Validation Loss: 1.000000
# Epoch [387/500], Iter [520], Train Loss: 0.159057, Validation Loss: 1.000000
# Epoch [388/500], Iter [520], Train Loss: 0.189142, Validation Loss: 1.000000
# Epoch [389/500], Iter [520], Train Loss: 0.273117, Validation Loss: 1.000000
# Epoch [390/500], Iter [520], Train Loss: 0.197846, Validation Loss: 1.000000
# Epoch [391/500], Iter [520], Train Loss: 0.171101, Validation Loss: 1.000000
# Epoch [392/500], Iter [520], Train Loss: 0.367717, Validation Loss: 1.000000
# Epoch [393/500], Iter [520], Train Loss: 0.253670, Validation Loss: 1.000000
# Epoch [394/500], Iter [520], Train Loss: 0.182258, Validation Loss: 1.000000
# Epoch [395/500], Iter [520], Train Loss: 0.205059, Validation Loss: 1.000000
# Epoch [396/500], Iter [520], Train Loss: 0.308669, Validation Loss: 1.000000
# Epoch [397/500], Iter [520], Train Loss: 0.248860, Validation Loss: 1.000000
# Epoch [398/500], Iter [520], Train Loss: 0.224177, Validation Loss: 1.000000
# Epoch [399/500], Iter [520], Train Loss: 0.277814, Validation Loss: 1.000000
# Epoch [400/500], Iter [520], Train Loss: 0.167876, Validation Loss: 1.000000
# Epoch [401/500], Iter [520], Train Loss: 0.206075, Validation Loss: 1.000000
# Epoch [402/500], Iter [520], Train Loss: 0.215180, Validation Loss: 1.000000
# Epoch [403/500], Iter [520], Train Loss: 0.183245, Validation Loss: 1.000000
# Epoch [404/500], Iter [520], Train Loss: 0.176021, Validation Loss: 1.000000
# Epoch [405/500], Iter [520], Train Loss: 0.207222, Validation Loss: 1.000000
# Epoch [406/500], Iter [520], Train Loss: 0.173781, Validation Loss: 1.000000
# Epoch [407/500], Iter [520], Train Loss: 0.183566, Validation Loss: 1.000000
# Epoch [408/500], Iter [520], Train Loss: 0.158301, Validation Loss: 1.000000
# Epoch [409/500], Iter [520], Train Loss: 0.171011, Validation Loss: 1.000000
# Epoch [410/500], Iter [520], Train Loss: 0.307351, Validation Loss: 1.000000
# Epoch [411/500], Iter [520], Train Loss: 0.168768, Validation Loss: 1.000000
# Epoch [412/500], Iter [520], Train Loss: 0.174508, Validation Loss: 1.000000
# Epoch [413/500], Iter [520], Train Loss: 0.206981, Validation Loss: 1.000000
# Epoch [414/500], Iter [520], Train Loss: 0.158427, Validation Loss: 1.000000
# Epoch [415/500], Iter [520], Train Loss: 0.172997, Validation Loss: 1.000000
# Epoch [416/500], Iter [520], Train Loss: 0.169723, Validation Loss: 1.000000
# Epoch [417/500], Iter [520], Train Loss: 0.183653, Validation Loss: 1.000000
# Epoch [418/500], Iter [520], Train Loss: 0.183683, Validation Loss: 1.000000
# Epoch [419/500], Iter [520], Train Loss: 0.176688, Validation Loss: 1.000000
# Epoch [420/500], Iter [520], Train Loss: 0.183772, Validation Loss: 1.000000
# Epoch [421/500], Iter [520], Train Loss: 0.176328, Validation Loss: 1.000000
# Epoch [422/500], Iter [520], Train Loss: 0.157512, Validation Loss: 1.000000
# Epoch [423/500], Iter [520], Train Loss: 0.191968, Validation Loss: 1.000000
# Epoch [424/500], Iter [520], Train Loss: 0.187697, Validation Loss: 1.000000
# Epoch [425/500], Iter [520], Train Loss: 0.179428, Validation Loss: 1.000000
# Epoch [426/500], Iter [520], Train Loss: 0.158538, Validation Loss: 1.000000
# Epoch [427/500], Iter [520], Train Loss: 0.216147, Validation Loss: 1.000000
# Epoch [428/500], Iter [520], Train Loss: 0.165772, Validation Loss: 1.000000
# Epoch [429/500], Iter [520], Train Loss: 0.173457, Validation Loss: 1.000000
# Epoch [430/500], Iter [520], Train Loss: 0.203351, Validation Loss: 1.000000
# Epoch [431/500], Iter [520], Train Loss: 0.468682, Validation Loss: 1.000000
# Epoch [432/500], Iter [520], Train Loss: 0.284965, Validation Loss: 1.000000
# Epoch [433/500], Iter [520], Train Loss: 0.231889, Validation Loss: 1.000000
# Epoch [434/500], Iter [520], Train Loss: 0.200557, Validation Loss: 1.000000
# Epoch [435/500], Iter [520], Train Loss: 0.184263, Validation Loss: 1.000000
# Epoch [436/500], Iter [520], Train Loss: 0.177550, Validation Loss: 1.000000
# Epoch [437/500], Iter [520], Train Loss: 0.180856, Validation Loss: 1.000000
# Epoch [438/500], Iter [520], Train Loss: 0.172821, Validation Loss: 1.000000
# Epoch [439/500], Iter [520], Train Loss: 0.188471, Validation Loss: 1.000000
# Epoch [440/500], Iter [520], Train Loss: 0.165912, Validation Loss: 1.000000
# Epoch [441/500], Iter [520], Train Loss: 0.195493, Validation Loss: 1.000000
# Epoch [442/500], Iter [520], Train Loss: 0.175394, Validation Loss: 1.000000
# Epoch [443/500], Iter [520], Train Loss: 0.264173, Validation Loss: 1.000000
# Epoch [444/500], Iter [520], Train Loss: 0.235623, Validation Loss: 1.000000
# Epoch [445/500], Iter [520], Train Loss: 0.219361, Validation Loss: 1.000000
# Epoch [446/500], Iter [520], Train Loss: 0.170532, Validation Loss: 1.000000
# Epoch [447/500], Iter [520], Train Loss: 0.159782, Validation Loss: 1.000000
# Epoch [448/500], Iter [520], Train Loss: 0.157398, Validation Loss: 1.000000
# Epoch [449/500], Iter [520], Train Loss: 0.244764, Validation Loss: 1.000000
# Epoch [450/500], Iter [520], Train Loss: 0.168090, Validation Loss: 1.000000
# Epoch [451/500], Iter [520], Train Loss: 0.156985, Validation Loss: 1.000000
# Epoch [452/500], Iter [520], Train Loss: 0.165527, Validation Loss: 1.000000
# Epoch [453/500], Iter [520], Train Loss: 0.175890, Validation Loss: 1.000000
# Epoch [454/500], Iter [520], Train Loss: 0.168747, Validation Loss: 1.000000
# Epoch [455/500], Iter [520], Train Loss: 0.223627, Validation Loss: 1.000000
# Epoch [456/500], Iter [520], Train Loss: 0.194084, Validation Loss: 1.000000
# Epoch [457/500], Iter [520], Train Loss: 0.177030, Validation Loss: 1.000000
# Epoch [458/500], Iter [520], Train Loss: 0.177564, Validation Loss: 1.000000
# Epoch [459/500], Iter [520], Train Loss: 0.182717, Validation Loss: 1.000000
# Epoch [460/500], Iter [520], Train Loss: 0.194659, Validation Loss: 1.000000
# Epoch [461/500], Iter [520], Train Loss: 0.174964, Validation Loss: 1.000000
# Epoch [462/500], Iter [520], Train Loss: 0.222954, Validation Loss: 1.000000
# Epoch [463/500], Iter [520], Train Loss: 0.268883, Validation Loss: 1.000000
# Epoch [464/500], Iter [520], Train Loss: 0.323938, Validation Loss: 1.000000
# Epoch [465/500], Iter [520], Train Loss: 0.183419, Validation Loss: 1.000000
# Epoch [466/500], Iter [520], Train Loss: 0.178518, Validation Loss: 1.000000
# Epoch [467/500], Iter [520], Train Loss: 0.196083, Validation Loss: 1.000000
# Epoch [468/500], Iter [520], Train Loss: 0.366646, Validation Loss: 1.000000
# Epoch [469/500], Iter [520], Train Loss: 0.253607, Validation Loss: 1.000000
# Epoch [470/500], Iter [520], Train Loss: 0.222876, Validation Loss: 1.000000
# Epoch [471/500], Iter [520], Train Loss: 0.172852, Validation Loss: 1.000000
# Epoch [472/500], Iter [520], Train Loss: 0.193296, Validation Loss: 1.000000
# Epoch [473/500], Iter [520], Train Loss: 0.190823, Validation Loss: 1.000000
# Epoch [474/500], Iter [520], Train Loss: 0.235214, Validation Loss: 1.000000
# Epoch [475/500], Iter [520], Train Loss: 0.160247, Validation Loss: 1.000000
# Epoch [476/500], Iter [520], Train Loss: 0.166336, Validation Loss: 1.000000
# Epoch [477/500], Iter [520], Train Loss: 0.175657, Validation Loss: 1.000000
# Epoch [478/500], Iter [520], Train Loss: 0.185424, Validation Loss: 1.000000
# Epoch [479/500], Iter [520], Train Loss: 0.168910, Validation Loss: 1.000000
# Epoch [480/500], Iter [520], Train Loss: 0.185059, Validation Loss: 1.000000
# Epoch [481/500], Iter [520], Train Loss: 0.181784, Validation Loss: 1.000000
# Epoch [482/500], Iter [520], Train Loss: 0.230510, Validation Loss: 1.000000
# Epoch [483/500], Iter [520], Train Loss: 0.197703, Validation Loss: 1.000000
# Epoch [484/500], Iter [520], Train Loss: 0.207687, Validation Loss: 1.000000
# Epoch [485/500], Iter [520], Train Loss: 0.138931, Validation Loss: 1.000000
# Epoch [486/500], Iter [520], Train Loss: 0.168474, Validation Loss: 1.000000
# Epoch [487/500], Iter [520], Train Loss: 0.167614, Validation Loss: 1.000000
# Epoch [488/500], Iter [520], Train Loss: 0.160540, Validation Loss: 1.000000
# Epoch [489/500], Iter [520], Train Loss: 0.172442, Validation Loss: 1.000000
# Epoch [490/500], Iter [520], Train Loss: 0.147587, Validation Loss: 1.000000
# Epoch [491/500], Iter [520], Train Loss: 0.146883, Validation Loss: 1.000000
# Epoch [492/500], Iter [520], Train Loss: 0.183884, Validation Loss: 1.000000
# Epoch [493/500], Iter [520], Train Loss: 0.184872, Validation Loss: 1.000000
# Epoch [494/500], Iter [520], Train Loss: 0.144486, Validation Loss: 1.000000
# Epoch [495/500], Iter [520], Train Loss: 0.174643, Validation Loss: 1.000000
# Epoch [496/500], Iter [520], Train Loss: 0.228628, Validation Loss: 1.000000
# Epoch [497/500], Iter [520], Train Loss: 0.237316, Validation Loss: 1.000000
# Epoch [498/500], Iter [520], Train Loss: 0.262863, Validation Loss: 1.000000
# Epoch [499/500], Iter [520], Train Loss: 0.180074, Validation Loss: 1.000000
# Epoch [500/500], Iter [520], Train Loss: 0.161226, Validation Loss: 1.000000

# %%
# Save the Trained Model
with open('cnn_KernSize' + str(kernel_size) + '_NoOfNeurons' + str(noOfNeurons) + '_ForPaper.pkl', 'wb') as pickle_file:
     torch.save(cnn.state_dict(), pickle_file)
np.savez('lossdata.npz', name1=trainLosses, name2=valLosses)

# %%
# Loading the model
with open('cnn_KernSize' + str(kernel_size) + '_NoOfNeurons' + str(noOfNeurons) + '_ForPaper.pkl', 'rb') as pickle_file:
     cnn.load_state_dict(torch.load(pickle_file))
#np.load('lossdata.npz')

# %%
# Plotting the training + validation losses
plt.plot(trainLosses,'-k')
plt.title("Training loss")
plt.xlabel("Epochs")
plt.ylabel("MSE")
fig.savefig('Figures/TrainingMSELoss.png', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
# Plotting various training results (impedance) with the input impedance

# Make one graph showing sample Training Data
sampleNumbers = np.array([2,54,123,209])

fig, axs = plt.subplots(1, 4, sharey=True)
axs[0].invert_yaxis()
fig.suptitle('Samples of Training Data Predictions')

# Seismic traces
for i in range(4):
    sampleNumber = sampleNumbers[i];
    
    # Get an input seismic and impedance trace 
    TrainingSeismicTrace = Variable(trainX[sampleNumber:sampleNumber+1,:,:]).cuda()
    TrainingImpedanceTrace = Variable(trainIp[sampleNumber:sampleNumber+1,:,0]).cuda();
    # Calculate the impedance prediction
    CNN_ImpedancePrediction = cnn(TrainingSeismicTrace)

    #Now Get the numpy versions
    TrainingSeismicTrace = trainX[sampleNumber,:].numpy().transpose()
    TrainingImpedanceTrace = trainIp[sampleNumber,:].numpy().transpose()
    CNN_ImpedancePrediction = CNN_ImpedancePrediction.data.cpu().numpy().transpose()[:, 0,0]
    
    line1, = axs[i].plot(TrainingImpedanceTrace, time, 'r-')
    axs[i].set_xlabel('Impedance')
    if i==0:
        axs[i].set_ylabel('Time(s)')
    line2, = axs[i].plot(CNN_ImpedancePrediction, time, 'k--')
lgd = plt.legend((line1, line2), ('True Impedance', 'CNN Impedance'), bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# fig.savefig('Figures/TrainigMatchesExamples.pdf', bbox_extra_artists=(lgd,), bbox_inches='tight', format='pdf', dpi=1200)

# Plotting various testing results (impedance) with the input impedance

# Make one graph showing sample Training Data
sampleNumbers = np.array([21,50,162,206])

fig, axs = plt.subplots(1, 4, sharey=True)
axs[0].invert_yaxis()
fig.suptitle('Samples of Testing Data Predictions')

# Seismic traces
for i in range(4):
    sampleNumber = sampleNumbers[i];
    
    # Get an input seismic and impedance trace 
    TestingSetSeismicTrace = Variable(testX[sampleNumber:sampleNumber+1,:,:]).cuda()
    TestingSetImpedanceTrace = Variable(testIp[sampleNumber:sampleNumber+1,:,0]).cuda();
    # Calculate the impedance prediction
    CNN_ImpedancePrediction = cnn(TestingSetSeismicTrace)

    #Now Get the numpy versions
    TestingSetSeismicTrace = testX[sampleNumber,:].numpy().transpose()
    TestingSetImpedanceTrace = testIp[sampleNumber,:].numpy().transpose()
    CNN_ImpedancePrediction = CNN_ImpedancePrediction.data.cpu().numpy().transpose()[:, 0,0]
    
    line1, = axs[i].plot(TestingSetImpedanceTrace, time, 'r-')
    axs[i].set_xlabel('Impedance')
    if i==0:
        axs[i].set_ylabel('Time(s)')
    line2, = axs[i].plot(CNN_ImpedancePrediction, time, 'k--')
lgd = plt.legend((line1, line2), ('True Impedance', 'CNN Impedance'), bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# fig.savefig('Figures/TestingMatchesExamples.png', bbox_extra_artists=(lgd,), bbox_inches='tight')

# Plotting various testing results (impedance) with the input impedance

# Make one graph showing sample Training Data
sampleNumbers = np.array([2,45,123,201])

fig, axs = plt.subplots(1, 4, sharey=True)
axs[0].invert_yaxis()
fig.suptitle('Samples of Predictions on Variograms Ranges Not Trained On')

# Seismic traces
for i in range(4):
    sampleNumber = sampleNumbers[i];
    
    # Get an input seismic and impedance trace 
    TestingHardSeismicTrace = TestingSeismic[sampleNumber,:];
    TestingHardImpedanceTrace = TestingImpedance[sampleNumber, :];
    # Calculate the impedance prediction
    TestingHardSeismicTraceTorch = torch.FloatTensor(np.reshape(TestingHardSeismicTrace, (1,1,  TestingHardSeismicTrace.shape[0])))
    TestingHardSeismicTraceTorch = Variable(TestingHardSeismicTraceTorch).cuda()
    CNN_ImpedancePrediction = cnn(TestingHardSeismicTraceTorch)

    #Now Get the numpy versions
    CNN_ImpedancePrediction = CNN_ImpedancePrediction.data.cpu().numpy().transpose()[:, 0,0]
    
    line1, = axs[i].plot(TestingHardImpedanceTrace, time, 'r-')
    axs[i].set_xlabel('Impedance')
    if i==0:
        axs[i].set_ylabel('Time(s)')
    line2, = axs[i].plot(CNN_ImpedancePrediction, time, 'k--')
lgd = plt.legend((line1, line2), ('True Impedance', 'CNN Impedance'), bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# fig.savefig('Figures/TestingHardMatchesExamples.pdf', bbox_extra_artists=(lgd,), bbox_inches='tight', format='pdf', dpi=1200)

# %%
import scipy

# Convolution model with favorite wavelet (minimum phase) vs zero=phase wavelet
sampleNumber = 10

TestingSetSeismicTrace = Variable(testX[sampleNumber:sampleNumber+1,:,:]).cuda()
TestingSetImpedanceTrace = Variable(testIp[sampleNumber:sampleNumber+1,:,0]).cuda();
# Calculate the impedance prediction
CNN_ImpedancePrediction = cnn(TestingSetSeismicTrace)

dataframe_source = sio.loadmat('minimum_phase_wavelet.mat')
source_min_phase = dataframe_source['src_wavelet']

# Convolution of source with reflectivity series 
impedance_min_phase_test = testIp[sampleNumber,:].numpy().transpose()
r0 = 0.5*np.diff(np.log(impedance_min_phase_test), axis=0)
r0 = np.insert(r0,0, 0)

dt_source = 0.0351/(2*30)
dt = 4.3875e-4
time = np.linspace(0,(TrainingSeismic.shape[1]-1)*dt,TrainingSeismic.shape[1])
time_source = np.arange(0, np.max(time), dt_source)
# time_source = np.reshape(time_source, (248,1))
source_new = scipy.interpolate.interp1d(time_source, source_min_phase[0:time_source.shape[0],0], fill_value="extrapolate")(time)

plt.plot(source_new)
plt.show()

ss = np.convolve(r0, source_new, mode='full')
ss = ss[0:impedance_min_phase_test.shape[0]]
seismic_min_phase_test = testX[sampleNumber,:].numpy().transpose()
min_seismic = np.min(seismic_min_phase_test)
max_seismic = np.max(seismic_min_phase_test)
ss_normalized = (max_seismic - min_seismic) * (ss - np.min(ss))/(np.max(ss) - np.min(ss)) + min_seismic

TestingSetSeismicTrace_min_phase = Variable(torch.FloatTensor(np.reshape(ss_normalized, (1,1,331)))).cuda()
TestingSetImpedanceTrace = Variable(testIp[sampleNumber:sampleNumber+1,:,0]).cuda();
# Calculate the impedance prediction
CNN_ImpedancePrediction_min_phase = cnn(TestingSetSeismicTrace_min_phase)


fig, axs = plt.subplots(1, 4, sharey=False)
axs[0].invert_yaxis()
axs[0].plot(impedance_min_phase_test, time)
axs[1].plot(r0, time)
axs[1].invert_yaxis()
line2, = axs[2].plot(ss_normalized, time, '-k')
line1, = axs[2].plot(seismic_min_phase_test, time, '--r')
# axs[2].plot(TestingSetSeismicTrace_min_phase.data.cpu().numpy().transpose()[:,0,0], time, '-b')
axs[2].invert_yaxis()
axs[3].plot(CNN_ImpedancePrediction.data.cpu().numpy().transpose()[:, 0,0], time, '--r')
axs[3].plot(CNN_ImpedancePrediction_min_phase.data.cpu().numpy().transpose()[:, 0,0], time, '--k')
axs[3].plot(impedance_min_phase_test, time, '-b')
axs[3].invert_yaxis()
lgd = plt.legend((line1, line2), ('Zero phase', 'Minimum phase'), bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
np.reshape(ss_normalized, (1,1,331)).shape
# Out:
# (1, 1, 331)

# %%
# Get the whole success rates using different metrics

testX = (TrainingSeismic[howManyToValidate:howManyToValidate+howManyToTest,fromWhich:tillWhich])
trainX = (TrainingSeismic[howManyToValidate+howManyToTest:,fromWhich:tillWhich])
testIp = (TrainingImpedance[howManyToValidate:howManyToValidate+howManyToTest,0:-fromWhich+tillWhich])
trainIp = (TrainingImpedance[howManyToValidate+howManyToTest:,0:-fromWhich+tillWhich])

n_train=trainIp.shape[0]
n_testhard=TestingSeismic.shape[0]
n_test=testX.shape[0]

#1
NormXCorrErrTraining = np.zeros((n_train))
NormXCorrErrTesting = np.zeros((n_test))
NormXCorrErrTestingHard = np.zeros((n_testhard))

#2
AverageAbsoluteErrorTraining = np.zeros((n_train))
AverageAbsoluteErrorTesting = np.zeros((n_test))
AverageAbsoluteErrorTestingHard = np.zeros((n_testhard))

#3
AverageRMSETraining =  np.zeros((n_train))
AverageRMSETesting =  np.zeros((n_test))
AverageRMSETestingHard =  np.zeros((n_testhard))

#4
AbsoluteErrorPercentageTraining =  np.zeros((n_train))
AbsoluteErrorPercentageTesting =  np.zeros((n_test))
AbsoluteErrorPercentageTestingHard =  np.zeros((n_testhard))

#5
L1normByMeanIpTrain = np.zeros((n_train))
L1normByMeanIpTest = np.zeros((n_test))
L1normByMeanIpTestingHard = np.zeros((n_testhard))

rangeAllImpedanceTraining = trainIp.max() - trainIp.min();
rangeAllImpedanceTesting = testIp.max() - testIp.min();
rangeAllImpedanceTestingHard = TestingImpedance.max() - TestingImpedance.min();

print('Range of all impedance is: ' + str(rangeAllImpedanceTesting))


#Get values for testing data
for i in range(n_train):
    sampleNumber = i
    if i%100==0:
        print(sampleNumber)
    
    #Get Data
    SeismicTrace = trainX[sampleNumber,:]
    IpTrace = trainIp[sampleNumber,:]

    SeismicTrace = torch.FloatTensor(np.reshape(SeismicTrace, (1,1, SeismicTrace.shape[0])))
    traces = Variable(SeismicTrace).cuda()
    outputs = cnn(traces)

    CNN_Impedance_Trace = outputs.data.cpu().numpy()[0,0,:]
    CNN_Impedance_Trace_norm = (CNN_Impedance_Trace - np.mean(CNN_Impedance_Trace)) / (np.std(CNN_Impedance_Trace) * len(CNN_Impedance_Trace))
    datasetIp_norm = (IpTrace - np.mean(IpTrace)) /  np.std(IpTrace)
    NormXCorrErrTraining[i] = (np.correlate(CNN_Impedance_Trace_norm, datasetIp_norm))
    
    AverageAbsoluteErrorTraining[i] = (np.absolute(IpTrace - CNN_Impedance_Trace)).mean()
    AverageRMSETraining[i] = np.sqrt(np.mean((IpTrace-CNN_Impedance_Trace)**2));
    AbsoluteErrorPercentageTraining[i] = 1-AverageAbsoluteErrorTraining[i]/rangeAllImpedanceTraining
    
    L1normByMeanIpTrain[i] = ((np.absolute(IpTrace - CNN_Impedance_Trace)).mean())/IpTrace.mean()

    
#Get values for testing data
for i in range(n_test):
    sampleNumber = i
    if i%100==0:
        print(sampleNumber)
    
    #Get Data
    SeismicTrace = testX[sampleNumber,:]
    IpTrace = testIp[sampleNumber,:]

    SeismicTrace = torch.FloatTensor(np.reshape(SeismicTrace, (1,1, SeismicTrace.shape[0])))
    traces = Variable(SeismicTrace).cuda()
    outputs = cnn(traces)

    CNN_Impedance_Trace = outputs.data.cpu().numpy()[0,0,:]
    CNN_Impedance_Trace_norm = (CNN_Impedance_Trace - np.mean(CNN_Impedance_Trace)) / (np.std(CNN_Impedance_Trace) * len(CNN_Impedance_Trace))
    datasetIp_norm = (IpTrace - np.mean(IpTrace)) /  np.std(IpTrace)
    NormXCorrErrTesting[i] = (np.correlate(CNN_Impedance_Trace_norm, datasetIp_norm))
    
    AverageAbsoluteErrorTesting[i] = (np.absolute(IpTrace - CNN_Impedance_Trace)).mean()
    AverageRMSETesting[i] = np.sqrt(np.mean((IpTrace-CNN_Impedance_Trace)**2));
    AbsoluteErrorPercentageTesting[i] = 1-AverageAbsoluteErrorTesting[i]/rangeAllImpedanceTesting
    
    L1normByMeanIpTest[i] = ((np.absolute(IpTrace - CNN_Impedance_Trace)).mean())/IpTrace.mean()
    
#Get values for testing hard data
for i in range(n_testhard):
    sampleNumber = i
    if i%100==0:
        print(sampleNumber)
    
    #Get Data
    SeismicTrace = TestingSeismic[sampleNumber,:]
    IpTrace = TestingImpedance[sampleNumber,:]

    SeismicTrace = torch.FloatTensor(np.reshape(SeismicTrace, (1,1, SeismicTrace.shape[0])))
    traces = Variable(SeismicTrace).cuda()
    outputs = cnn(traces)

    CNN_Impedance_Trace = outputs.data.cpu().numpy()[0,0,:]
    CNN_Impedance_Trace_norm = (CNN_Impedance_Trace - np.mean(CNN_Impedance_Trace)) / (np.std(CNN_Impedance_Trace) * len(CNN_Impedance_Trace))
    datasetIp_norm = (IpTrace - np.mean(IpTrace)) /  np.std(IpTrace)
    NormXCorrErrTestingHard[i] = (np.correlate(CNN_Impedance_Trace_norm, datasetIp_norm))
    
    AverageAbsoluteErrorTestingHard[i] = (np.absolute(IpTrace - CNN_Impedance_Trace)).mean()
    AverageRMSETestingHard[i] = np.sqrt(np.mean((IpTrace-CNN_Impedance_Trace)**2));
    AbsoluteErrorPercentageTestingHard[i] = 1-AverageAbsoluteErrorTesting[i]/rangeAllImpedanceTestingHard
    
    L1normByMeanIpTestingHard[i] = ((np.absolute(IpTrace - CNN_Impedance_Trace)).mean())/IpTrace.mean()
# Out:
# Range of all impedance is: 7.23024986061
# 0
# 100
# 200
# 300
# 400
# 500
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 0
# 100
# 200
# 300
# 400
# 500
# 600

# %%
# Look at the weights
parameters_list = []

for name, param in cnn.named_parameters():
    print(name, param.data)
    parameters_list.append(param.data)

plt.imshow(parameters_list[2].cpu().numpy()[0,:,:], aspect='auto', cmap='jet', vmin= -0.01, vmax = 0.01)
plt.show()

last_layer_weights = parameters_list[2].cpu().numpy()

for i in range(last_layer_weights.shape[1]):
    plt.plot(last_layer_weights[0,i,:])
# Out:
# layer1.0.weight
# ( 0 ,.,.) =
# 1.00000e-02 *
#  -4.4428  5.7176  1.3359  ...  -2.2205 -2.6863  3.4097
#
# ( 1 ,.,.) =
# 1.00000e-02 *
#   4.4366 -1.1407 -3.3663  ...  -5.5137  2.9256 -0.5273
#
# ( 2 ,.,.) =
# 1.00000e-02 *
#   3.4955  2.5361  1.9960  ...   5.4422  4.7731  4.4891
# ...
#
# (57 ,.,.) =
# 1.00000e-02 *
#   4.4553 -4.0505  1.2493  ...   2.1909 -5.1572 -4.4394
#
# (58 ,.,.) =
# 1.00000e-02 *
#   0.3009 -4.2335  1.9515  ...   0.0971 -0.1171 -3.2200
#
# (59 ,.,.) =
# 1.00000e-02 *
#  -3.8977  1.5626  0.0933  ...  -0.1400 -3.2849  1.9906
# [torch.cuda.FloatTensor of size 60x1x300 (GPU 0)]
#
# layer1.0.bias
# 1.00000e-02 *
#  -4.9154
#   0.0588
#   1.9702
#  -0.6537
#   2.9744
#   0.0644
#   3.1106
#   4.6248
#   2.2096
#   2.7757
#  -2.1140
#   0.6973
#  -3.7261
#   3.7201
#  -2.7676
#  -5.4124
#   2.9268
#   2.3940
#  -3.0408
#  -1.0373
#  -5.7541
#   4.2815
#   4.3639
#   1.4286
#  -1.1718
#   3.1134
#   3.5557
#   4.7336
#  -0.5773
#  -3.0336
#  -2.4430
#   2.1596
#  -5.4475
#  -0.0199
#   3.6584
#  -1.9935
#   2.4858
#   0.7484
#  -2.3653
#   5.6897
#  -2.3884
#   3.6967
#  -4.5213
#   4.1665
#  -1.1617
#   1.5502
#   1.9864
#  -4.1077
#   0.0359
#   0.0063
#   4.5946
#  -4.0485
#  -2.5557
#  -5.2023
#  -2.9112
#  -1.3331
#   4.1881
#   2.6212
#  -2.1866
#   4.4263
# [torch.cuda.FloatTensor of size 60 (GPU 0)]
#
# layer2.0.weight
# ( 0 ,.,.) =
# 1.00000e-03 *
#  -4.8842 -5.3061 -1.2849  ...  -7.0750 -7.2764  4.1535
#   6.6959  6.4440 -6.8162  ...   3.6601 -3.9056  5.3715
#   5.8029  2.4604 -3.9805  ...  -2.6262 -2.7535 -5.9620
#            ...             ⋱             ...
#  -4.9171 -1.3851 -5.5345  ...   4.0314  5.6800  0.8024
#  -1.6362 -3.4800  1.6534  ...  -1.2470  0.1497  4.0200
#  -1.4147 -4.2945  2.1367  ...   6.1214 -5.5755  0.1573
# [torch.cuda.FloatTensor of size 1x60x300 (GPU 0)]
#
# layer2.0.bias
# 1.00000e-03 *
#  -5.8008
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %%
np.savetxt('VariogramTrain.dat',AverageAbsoluteErrorTraining , delimiter=',')
np.savetxt('VariogramTest.dat',AverageAbsoluteErrorTesting , delimiter=',')
np.savetxt('VariogramHard.dat',AverageAbsoluteErrorTestingHard , delimiter=',')

# %%
L1normByMeanIpTest
# Out:
# array([ 0.0535143 ,  0.04834861,  0.05200633,  0.04747955,  0.04977008,
#         0.04339205,  0.05806451,  0.07037959,  0.05420061,  0.05141586,
#         0.04086026,  0.04302868,  0.05204474,  0.0540482 ,  0.05254472,
#         0.03982435,  0.04521935,  0.04744294,  0.0531747 ,  0.04265436,
#         0.04215793,  0.04478136,  0.04639705,  0.04345171,  0.04698642,
#         0.04870729,  0.05467723,  0.04386948,  0.04103036,  0.05747769,
#         0.04635008,  0.04764645,  0.04409655,  0.0436715 ,  0.03924149,
#         0.04818381,  0.0528601 ,  0.05605209,  0.04228632,  0.05590936,
#         0.05629962,  0.06336617,  0.05306537,  0.06614698,  0.04289803,
#         0.04048817,  0.04702624,  0.05218896,  0.04603056,  0.05692319,
#         0.04195451,  0.03854365,  0.05670589,  0.10672595,  0.0377251 ,
#         0.05982176,  0.05203568,  0.05439804,  0.07222916,  0.04267596,
#         0.05085053,  0.0636768 ,  0.04945325,  0.04116927,  0.05708049,
#         0.05567325,  0.04702624,  0.04950862,  0.04444307,  0.0482002 ,
#         0.044479  ,  0.04296744,  0.04444307,  0.04740415,  0.05987023,
#         0.047446  ,  0.05832113,  0.0433649 ,  0.0592904 ,  0.05587616,
#         0.04829085,  0.04442401,  0.04949774,  0.04960662,  0.05237826,
#         0.0476691 ,  0.0412213 ,  0.04113414,  0.04194101,  0.05455883,
#         0.04364752,  0.0415682 ,  0.05664062,  0.04886111,  0.05069287,
#         0.07808809,  0.04356498,  0.03817096,  0.05844309,  0.06002381,
#         0.04736508,  0.04680251,  0.04190556,  0.05109402,  0.0627451 ,
#         0.05078001,  0.04668244,  0.05254676,  0.04838403,  0.06342755,
#         0.04579422,  0.04659617,  0.06280826,  0.04453065,  0.05714866,
#         0.04043645,  0.05365718,  0.06216242,  0.04316448,  0.04265436,
#         0.03952081,  0.05100929,  0.0502753 ,  0.04492144,  0.05241503,
#         0.07592705,  0.05438525,  0.09974029,  0.0421031 ,  0.08997299,
#         0.08382407,  0.06781975,  0.04041692,  0.04274862,  0.05150529,
#         0.04441465,  0.05747027,  0.05085837,  0.04591326,  0.05649163,
#         0.05334772,  0.05590936,  0.03982435,  0.0511161 ,  0.08311078,
#         0.04617295,  0.05830449,  0.0473017 ,  0.04683243,  0.03896628,
#         0.04374034,  0.04960274,  0.04343087,  0.05174297,  0.04206405,
#         0.06216242,  0.04753261,  0.05328584,  0.07775281,  0.05417227,
#         0.0636768 ,  0.04668244,  0.04235643,  0.04656034,  0.04946217,
#         0.03851027,  0.07326513,  0.04997289,  0.04626394,  0.04808283,
#         0.06860273,  0.05354673,  0.03755982,  0.04638945,  0.09212116,
#         0.07307527,  0.04765639,  0.04701718,  0.0600983 ,  0.050963  ,
#         0.04876707,  0.07775281,  0.04563882,  0.04752403,  0.05295403,
#         0.0495787 ,  0.05488262,  0.05265212,  0.09167904,  0.04477535,
#         0.06342755,  0.04606049,  0.10885339,  0.05347894,  0.07176935,
#         0.03672365,  0.05524247,  0.05371564,  0.04361566,  0.08619325,
#         0.04506709,  0.0443425 ,  0.05513014,  0.05245024,  0.0454653 ,
#         0.07037981,  0.0532511 ,  0.05489806,  0.05002041,  0.05325877,
#         0.0515058 ,  0.04049942,  0.04058962,  0.04936553,  0.05590936,
#         0.05088023,  0.06644132,  0.04755736,  0.04557198,  0.05209317,
#         0.04736508,  0.05693312,  0.04958181,  0.06300678,  0.06482785,
#         0.05477743,  0.04992576,  0.05644166,  0.05231242,  0.06139276,
#         0.04086026,  0.05279542,  0.04322668,  0.04310236,  0.04925139,
#         0.10042385,  0.0496703 ,  0.05094768,  0.04306206,  0.05789566,
#         0.06251644,  0.05009515,  0.04195644,  0.05507318,  0.05756153,
#         0.04404993,  0.04611985,  0.10885339,  0.06170288,  0.06798013,
#         0.0451632 ,  0.06505722,  0.06136942,  0.04783101,  0.10321885,
#         0.0421478 ,  0.04960274,  0.0662635 ,  0.12836096,  0.05614281,
#         0.03924149,  0.05082253,  0.04850062,  0.0739316 ,  0.04505428,
#         0.05516544,  0.04492144,  0.04057213,  0.04450625,  0.0421031 ,
#         0.04745772,  0.05305985,  0.06534557,  0.04144199,  0.06798013,
#         0.05741842,  0.04922291,  0.04457144,  0.04523308,  0.05391997,
#         0.05449033,  0.04982996,  0.0663193 ,  0.06660298,  0.04555961,
#         0.04739891,  0.06914183,  0.05529279,  0.05207518,  0.08661722,
#         0.04219059,  0.0580361 ,  0.04799407,  0.0568603 ,  0.04752235,
#         0.04503792,  0.04492144,  0.04560522,  0.04759265,  0.0800861 ,
#         0.06517311,  0.04992576,  0.05439804,  0.04523517,  0.03947358,
#         0.03998408,  0.04601782,  0.0673509 ,  0.04430408,  0.11983454,
#         0.05531098,  0.12103949,  0.04278744,  0.04871442,  0.04841412,
#         0.0687667 ,  0.06272127,  0.09110268,  0.04149475,  0.04970853,
#         0.04821473,  0.05237826,  0.04991838,  0.05111449,  0.04451642,
#         0.04213809,  0.0568603 ,  0.05389249,  0.05333314,  0.0470892 ,
#         0.05620115,  0.04228904,  0.05075817,  0.05798537,  0.0568603 ,
#         0.04423152,  0.04269083,  0.05838092,  0.04730804,  0.05328584,
#         0.04228632,  0.04680251,  0.05002041,  0.05531702,  0.05259132,
#         0.06645182,  0.04453569,  0.10097012,  0.04320605,  0.04444276,
#         0.0555925 ,  0.04833359,  0.0505677 ,  0.04812099,  0.04799407,
#         0.05934753,  0.05085837,  0.04774969,  0.06017292,  0.04595563,
#         0.04934427,  0.05924937,  0.07614215,  0.0725426 ,  0.0760502 ,
#         0.05541599,  0.04321301,  0.05705563,  0.03751848,  0.04073798,
#         0.06794604,  0.05103906,  0.05633709,  0.06431419,  0.04032152,
#         0.04183296,  0.05211659,  0.04073336,  0.0518649 ,  0.06211012,
#         0.05265248,  0.04931042,  0.05558992,  0.05163956,  0.05774987,
#         0.06035005,  0.05562023,  0.06527946,  0.07777535,  0.05522243,
#         0.04884442,  0.04267596,  0.07246657,  0.05670828,  0.05758448,
#         0.03748333,  0.0381669 ,  0.08311078,  0.04955947,  0.04460766,
#         0.04740415,  0.04628222,  0.04265436,  0.05204474,  0.0580354 ,
#         0.04457144,  0.04633687,  0.11073849,  0.06766443,  0.04377579,
#         0.05894778,  0.05216609,  0.06280826,  0.05294042,  0.05381522,
#         0.05156877,  0.07418123,  0.0487032 ,  0.04430408,  0.0627451 ,
#         0.09110268,  0.05360516,  0.04563882,  0.07657063,  0.05015103,
#         0.04794967,  0.05894289,  0.04946127,  0.07278128,  0.05169444,
#         0.06935699,  0.04703405,  0.04314736,  0.05567325,  0.05254472,
#         0.0512932 ,  0.05617654,  0.03513952,  0.109041  ,  0.06238623,
#         0.05342258,  0.04296985,  0.04783101,  0.05125792,  0.09212116,
#         0.11091168,  0.04231278,  0.06002381,  0.04918278,  0.04963516,
#         0.04961758,  0.064384  ,  0.04656289,  0.04605727,  0.05958548,
#         0.04517974,  0.06342755,  0.05372222,  0.04357887,  0.05254472,
#         0.04704892,  0.04170548,  0.05130276,  0.04736508,  0.04028332,
#         0.04404993,  0.04772026,  0.06372766,  0.05267337,  0.05132522,
#         0.04968473,  0.04681929,  0.11983454,  0.04042918,  0.05218529,
#         0.04386948,  0.07418123,  0.04857307,  0.05388174,  0.0526101 ,
#         0.04135389,  0.05329637,  0.05737438,  0.22326633,  0.04585415,
#         0.0399218 ,  0.05013332,  0.05333314,  0.04998233,  0.04931768,
#         0.06362253,  0.05389249,  0.05951601,  0.06816367,  0.0476691 ,
#         0.06660298,  0.04530639,  0.04542002,  0.04856956,  0.05849572,
#         0.05742034,  0.07572254,  0.04803945,  0.05763371,  0.05150165,
#         0.07281462,  0.08685265,  0.05844309,  0.05224712,  0.04669829,
#         0.33904553,  0.06139909,  0.053521  ,  0.05149254,  0.04329312,
#         0.07326513,  0.05204474,  0.05209317,  0.05814422,  0.04468112,
#         0.0511161 ,  0.05431632,  0.04923363,  0.04468112,  0.03984122,
#         0.10321885,  0.04086026,  0.05737438,  0.04615603,  0.04395253,
#         0.04310288,  0.05149254,  0.04856956,  0.15999317,  0.07353764,
#         0.05521095,  0.05837902,  0.05161377,  0.04448839,  0.07572254,
#         0.04349153,  0.05673299,  0.07572254,  0.03960127,  0.04274862,
#         0.05047693,  0.04565681,  0.05233363,  0.05009906,  0.04847432,
#         0.05031743,  0.05253783,  0.05025665,  0.05692319,  0.09125708,
#         0.05240002,  0.07657063,  0.05100929,  0.04620239,  0.05241503,
#         0.05628683,  0.04785981,  0.07145225,  0.09398976,  0.0371079 ,
#         0.05719247,  0.05041741,  0.05987023,  0.05932856,  0.0535339 ,
#         0.05461796,  0.05371564,  0.04617295,  0.04641469,  0.06588227,
#         0.05116138,  0.04768321,  0.05341636,  0.04606049,  0.04020346,
#         0.04714777,  0.07808809,  0.04444307,  0.05121934,  0.0384576 ,
#         0.04847101,  0.04857307,  0.07096004,  0.05670589,  0.05131274,
#         0.07798671,  0.04725694,  0.06318756,  0.05729824,  0.04417392,
#         0.04256651,  0.08882118,  0.05150687,  0.05271231,  0.05132565,
#         0.04655929,  0.04047896,  0.05559753,  0.04702418,  0.04408916,
#         0.04899074,  0.04194482,  0.06143205,  0.0421121 ,  0.09125708,
#         0.06372766,  0.06575649,  0.04897684,  0.0717078 ,  0.04144199,
#         0.04729818,  0.04015771,  0.05191845,  0.0573339 ,  0.04748975,
#         0.04322019,  0.03814918,  0.05213599,  0.05124824,  0.05635936,
#         0.0384576 ,  0.04544931,  0.04226524,  0.03490696,  0.05929536,
#         0.04949471,  0.04796038,  0.05265248,  0.04384564,  0.04774969,
#         0.05453973,  0.05156877,  0.04408916,  0.04908889,  0.04822686,
#         0.05924937,  0.04120075,  0.04883932,  0.04226524,  0.05153358,
#         0.05148855,  0.04681878,  0.04871182,  0.07222916,  0.05522268,
#         0.05763371,  0.04396552,  0.06645182,  0.03814918,  0.0898428 ,
#         0.05932856,  0.17332323,  0.03751848,  0.06600572,  0.04767987,
#         0.04140519,  0.05025665,  0.03523117,  0.04923363,  0.04251038,
#         0.04888562,  0.04374084,  0.0451985 ,  0.05382363,  0.04170548,
#         0.040884  ,  0.04704892,  0.03447115,  0.05253783,  0.04520285,
#         0.04547695,  0.04467951,  0.04576588,  0.04288518,  0.05742034,
#         0.06257729,  0.05015103,  0.04775637,  0.04954333,  0.04584345,
#         0.02305004,  0.06128577,  0.05347894,  0.05674837,  0.06019935,
#         0.0494171 ,  0.04748975,  0.05667296,  0.04566405,  0.06387323,
#         0.04767871,  0.05192939,  0.03970614,  0.04427043,  0.04453569,
#         0.04755445,  0.05558647,  0.04195201,  0.05038814,  0.05541382,
#         0.0508266 ,  0.05725712,  0.04649461,  0.0745016 ,  0.05975559,
#         0.05419817,  0.0638636 ,  0.06269022,  0.04144199,  0.06032564,
#         0.04709889,  0.0347063 ,  0.03410671,  0.05380479,  0.03911321,
#         0.05049244,  0.04140519,  0.11091168,  0.0618457 ,  0.06040007,
#         0.0399218 ,  0.04556277,  0.04228904,  0.04442401,  0.05709589,
#         0.06555458,  0.06331906,  0.10886985,  0.04031276,  0.05669357,
#         0.06494477,  0.04794967,  0.06097037,  0.04662187,  0.0462833 ,
#         0.08131057,  0.05525745,  0.06284208,  0.0717078 ,  0.04444696,
#         0.05300269,  0.05616037,  0.04544449,  0.0629286 ,  0.04442609,
#         0.05079169,  0.05689727,  0.04538045,  0.04458115,  0.04345171,
#         0.0540482 ,  0.05280064,  0.07181606,  0.04447192,  0.05279717,
#         0.04785981,  0.05604171,  0.0548469 ,  0.04492144,  0.13255099,
#         0.05148855,  0.04608547,  0.05042635,  0.04669829,  0.0534854 ,
#         0.04604471,  0.04192048,  0.04944788,  0.0451293 ,  0.06044963,
#         0.05399741,  0.0500309 ,  0.05945901,  0.05195064,  0.066799  ,
#         0.06170288,  0.04423152,  0.05071699,  0.05235658,  0.05991146,
#         0.04633687,  0.04520246,  0.04553875,  0.04354762,  0.0725426 ,
#         0.05245024,  0.05574971,  0.05510698,  0.04430322,  0.05161377,
#         0.07070179,  0.04189626,  0.05693312,  0.04508987,  0.04752235,
#         0.05328881,  0.06130445,  0.05437613,  0.03675594,  0.05174297,
#         0.0760502 ,  0.04656289,  0.04730804,  0.04994209,  0.05309634,
#         0.048588  ,  0.04628023,  0.05227868,  0.14071281,  0.05100263,
#         0.05844309,  0.04442609,  0.04853691,  0.05948853,  0.04426983,
#         0.04289803,  0.05191845,  0.03674377,  0.06518503,  0.04963516,
#         0.04998233,  0.0426918 ,  0.04681929,  0.07246657,  0.05692319,
#         0.04043645,  0.12009154,  0.0442891 ,  0.04701718,  0.06231187,
#         0.05021534,  0.06808202,  0.04103866,  0.04276939,  0.03646408,
#         0.03744869,  0.04833359,  0.0549068 ,  0.09125708,  0.06645182,
#         0.06117021,  0.06384318,  0.06849904,  0.04379711,  0.04172115,
#         0.04503887,  0.18041835,  0.04378675,  0.04442401,  0.04847432,
#         0.05036168,  0.04458115,  0.04507022,  0.05157577,  0.04351218,
#         0.05930919,  0.10626023,  0.04834407,  0.04192428,  0.05700363,
#         0.04882914,  0.04801394,  0.05756153,  0.05510698,  0.04116927,
#         0.0573944 ,  0.06035005,  0.05169238,  0.03559394,  0.05522268,
#         0.04819181,  0.049068  ,  0.06260023,  0.04566405,  0.04401807,
#         0.04925139,  0.03704287,  0.06623407,  0.05067151,  0.05868669,
#         0.08880992,  0.10321885,  0.04568187,  0.04917196,  0.05917806,
#         0.06536669,  0.05025665,  0.05294042,  0.04865044,  0.05726481,
#         0.05375483,  0.04465425,  0.06282833,  0.055316  ,  0.04993191,
#         0.0447825 ,  0.0456087 ,  0.04492144,  0.04740827,  0.05497312,
#         0.05350892,  0.06860273,  0.03559394,  0.05789566,  0.05188495,
#         0.04761988,  0.08870255,  0.04719554,  0.06565244,  0.03513952,
#         0.05382363,  0.04058962,  0.0745016 ,  0.04401632,  0.04764645,
#         0.03944395,  0.04970196,  0.05437613,  0.06211012,  0.05094768,
#         0.06593736,  0.04505502,  0.0470892 ,  0.04529418,  0.04871182,
#         0.05311707,  0.06434283,  0.0444952 ,  0.05246105,  0.05471325,
#         0.04871182,  0.04708896,  0.0540915 ,  0.0518179 ,  0.06462976,
#         0.04878374,  0.06002381,  0.04602204,  0.05872907,  0.04606049,
#         0.11905164,  0.05436009,  0.05034054,  0.06983643,  0.0511161 ,
#         0.08027574,  0.0535339 ,  0.05197174,  0.07037959,  0.04514613,
#         0.05225871,  0.04830421,  0.03947358,  0.05259569,  0.05000055,
#         0.04342077,  0.06211012,  0.05258639,  0.0480384 ,  0.0474948 ,
#         0.05676361,  0.04904662,  0.0477624 ,  0.04012139,  0.06282833,
#         0.05813486,  0.05308258,  0.0445611 ,  0.04396376,  0.04598073,
#         0.0505584 ,  0.05056274,  0.07037981,  0.0540915 ,  0.08523155,
#         0.05246105,  0.04996566,  0.06257729,  0.04704892,  0.04221958,
#         0.04498298,  0.06229703,  0.04659617,  0.05080085,  0.04725445,
#         0.04437535,  0.06091725,  0.06971261,  0.04752573,  0.08282876,
#         0.05593444,  0.05197867,  0.0441219 ,  0.05580508,  0.04881115])

# %%
np.savetxt('PercentVariogramTrain.dat',L1normByMeanIpTrain , delimiter=',')
np.savetxt('PercentVariogramTest.dat',L1normByMeanIpTest , delimiter=',')
np.savetxt('PercentVariogramHard.dat',L1normByMeanIpTestingHard , delimiter=',')

# %%
nbinshistogram = 60
smoothingFactor = 100; # higher is smoother


fig = plt.figure()
sns.set_style('whitegrid')
plt.xlabel('Absolute Success Percentage Distribution (%)')
plt.ylabel('Probability')
plt.title('Absolute Error Percentage of Predictions')

Line_AbsErrPercentTraining = sns.kdeplot(np.array(AbsoluteErrorPercentageTraining), bw=0.001, cut=0, label='Training')
ErrorPercentageTrainData = Line_AbsErrPercentTraining.get_lines()[0].get_data()
np.savetxt('averageErrorTrainPercent.dat', ErrorPercentageTrainData, delimiter=',')

Line_AbsErrPercentTesting = sns.kdeplot(np.array(AbsoluteErrorPercentageTesting), bw=0.001, cut=0, label='Testing')
ErrorPercentageTestData = Line_AbsErrPercentTesting.get_lines()[0].get_data()
np.savetxt('averageErrorTestPercent.dat', ErrorPercentageTestData, delimiter=',')

Line_AbsErrPercentTestingHard = sns.kdeplot(np.array(AbsoluteErrorPercentageTestingHard), bw=0.001, cut=0, label='TestingHard')
ErrorPercentageTestDataHard = Line_AbsErrPercentTestingHard.get_lines()[0].get_data()
np.savetxt('averageErrorTestPercentHard.dat', ErrorPercentageTestDataHard, delimiter=',')

lgd = plt.legend() 

fig.savefig('Figures/AverageErrorPercentagePrediction.png') 

fig = plt.figure()
sns.set_style('whitegrid')
plt.xlabel('Absolute Success Percentage Distribution (%)')
plt.ylabel('Probability')
plt.title('Average Absolute Error of Predictions')

Line_AbsErrPercentTraining = sns.kdeplot(np.array(AverageAbsoluteErrorTraining), bw=0.01, cut=0, label='Training')
ErrorPercentageTrainData = Line_AbsErrPercentTraining.get_lines()[0].get_data()
np.savetxt('averageErrorTrainAbs.dat', ErrorPercentageTrainData, delimiter=',')

Line_AbsErrPercentTesting = sns.kdeplot(np.array(AverageAbsoluteErrorTesting), bw=0.01, cut=0, label='Testing')
ErrorPercentageTestData = Line_AbsErrPercentTesting.get_lines()[0].get_data()
np.savetxt('averageErrorTestAbs.dat', ErrorPercentageTestData, delimiter=',')

Line_AbsErrPercentTestingHard = sns.kdeplot(np.array(AverageAbsoluteErrorTestingHard), bw=0.01, cut=0, label='TestingHard')
ErrorPercentageTestDataHard = Line_AbsErrPercentTestingHard.get_lines()[0].get_data()
np.savetxt('averageErrorTestAbsHard.dat', ErrorPercentageTestDataHard, delimiter=',')

lgd = plt.legend() 

fig.savefig('Figures/AverageErrorPrediction.png')

# %%
fig = plt.figure()
fig, axs =plt.subplots(1,2)

n, bins, patches = axs[1].hist(AverageAbsoluteErrorTraining, 50, density=True, facecolor='g', alpha=0.5)
n, bins, patches = axs[1].hist(AverageAbsoluteErrorTesting, 50, density=True, facecolor='r', alpha=0.5)
n, bins, patches = axs[1].hist(AverageAbsoluteErrorTestingHard, 50, density=True, facecolor='b', alpha=0.5)
plt.axis([0, 1.5, 0, 7])

data = [[NormXCorrErrTraining.mean(),NormXCorrErrTesting.mean(),NormXCorrErrTestingHard.mean()] ,
        [NormXCorrErrTraining.std(),NormXCorrErrTesting.std(),NormXCorrErrTestingHard.std()],
        [AverageAbsoluteErrorTraining.mean(),AverageAbsoluteErrorTesting.mean(),AverageAbsoluteErrorTestingHard.mean()],
        [AverageAbsoluteErrorTraining.std(),AverageAbsoluteErrorTesting.std(),AverageAbsoluteErrorTestingHard.std()],
        [AverageRMSETraining.mean(),AverageRMSETesting.mean(),AverageRMSETestingHard.mean()], 
        [AverageRMSETraining.std(),AverageRMSETesting.std(),AverageRMSETestingHard.std()], 
        [AbsoluteErrorPercentageTraining.mean(),AbsoluteErrorPercentageTesting.mean(),AbsoluteErrorPercentageTestingHard.mean()],
        [AbsoluteErrorPercentageTraining.std(),AbsoluteErrorPercentageTesting.std(),AbsoluteErrorPercentageTestingHard.std()]]


# NormXCorrErrTraining[i] = (np.correlate(CNN_Impedance_Trace_norm, datasetIp_norm))
    
#     AverageAbsoluteErrorTraining[i] = (np.absolute(IpTrace - CNN_Impedance_Trace)).mean()
#     AverageRMSETraining[i] = np.sqrt(np.mean((IpTrace-CNN_Impedance_Trace)**2));
#     AbsoluteErrorPercentageTraining[i] = 1-AverageAbsoluteErrorTraining[i]/rangeAllImpedanceTraining


columns = ('Train', 'Test', 'TestHard')
rows = ['NormXCorrErr Mean', 'NormXCorrErr std',
        'AverageAbsoluteError Mean', 'AverageAbsoluteError std',
        'AverageRMSE Mean','AverageRMSE std', 
        'AbsoluteErrorPercentage mean', 'AbsoluteErrorPercentage std']
n_rows = len(rows)
y_offset = np.zeros(len(columns))

# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    cell_text.append(['%1.3f' % (x) for x in data[row]])

axs[0].axis('tight')
axs[0].axis('off')
# Add a table at the bottom of the axes
the_table = axs[0].table(cellText=cell_text,
                      rowLabels=rows,
                      colLabels=columns,
                      loc='center')

# Adjust layout to make room for the table:
fig.savefig('Figures/TableErrors.png')

# %%
#The BIG Trash can

#plot some seismic line
whichSample = 280
numberSamples = testX.shape[2]
traces = testX[whichSample:whichSample+1,:,50:].numpy()

xvals = np.linspace(0, traces.shape[2], numberSamples)
x1 = np.linspace(0, traces.shape[2], traces.shape[2])

yinterp = np.interp(xvals, x1, traces[0,0,:])

plt.plot(xvals, yinterp)
plt.plot(x1,traces[0,0,:],'-r')

testIp.shape

#plot predicted + true impedance and seismic on same line
traces = Variable(torch.FloatTensor(np.reshape(yinterp, (1, 1, yinterp.shape[0])))).cuda()
# traces = Variable(torch.FloatTensor(yinterp)).cuda()

yy = Variable(testIp[whichSample:whichSample+1,:,0]).cuda();
outputs = cnn(traces)
#print(truRC.shape)
#truRC = testY[whichSample,:].numpy()

truIp = testIp[whichSample,0,50:].numpy()
truIp = np.interp(xvals, x1, truIp)
input1 = testX[whichSample,0,50:].numpy()
line1, = plt.plot(outputs.data.cpu().numpy()[0,0,:],'r')
line2, = plt.plot(truIp,'--k')
plt.title("Test data")
plt.xlabel("Index")
plt.ylabel("Impedance")
plt.legend((line1, line2), ('CNN Impedance', 'True Impedance'))

plt.plot(yinterp*3)

#######################################################################################
# Plotting the test result

whichSample = 50
fig = plt.figure()
traces = Variable(testX[whichSample:whichSample+1,:,:]).cuda()
yy = Variable(testIp[whichSample:whichSample+1,:,0]).cuda();
outputs = cnn(traces)
# truRC = testY[whichSample,:].numpy()
truIp = testIp[whichSample,:].numpy()
input1 = testX[whichSample,:].numpy()
line1, = plt.plot(outputs.data.cpu().numpy()[0,0,:],'r')
line2, = plt.plot(truIp[0,:],'--k')
plt.title("Test data")
plt.xlabel("Index")
plt.ylabel("Impedance")
plt.legend((line1, line2), ('CNN Impedance', 'True Impedance'))
fig.savefig('Figures/TestingDataImpedancePrediction.png') 
##########################################################################################
datasetXRicker = torch.FloatTensor(np.reshape(datasetXRicker, (1,1, datasetXRicker.shape[0])))

plt.plot(testX[1,0,:].numpy())
plt.plot(datasetXRicker[0,0,:].numpy())
#######################################################################################
mu = np.mean(NormXCorrErr)
sigma = np.std(NormXCorrErr)

# the histogram of the data
n, bins, patches = plt.hist(NormXCorrErr, 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Normalized Cross Correlation Coeffcient')
plt.ylabel('Probability')
plt.title('Histogram of Normalized X-Cor Coefficient Accuracy Metric (Test Hard)')
plt.text(0.20, 2, r'$\mu='+str(mu)+',\ \sigma=' + str(sigma) +'$')
#plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

####################
nbins = 100
fig = plt.figure()
plt.xlabel('Normalized Cross Correlation Coeffcient and AbsoluteErrorPercentag')
plt.ylabel('Probability')
plt.title('Normalized Error Plots')
p, x = np.histogram(NormXCorrErr, bins=nbins) # bin it into n = N//10 bins
x = x[:-1] + (x[1] - x[0])/2   # convert bin edges to centers
f = UnivariateSpline(x, p, s=nbins)
line1, = plt.plot(x, f(x))

p, x = np.histogram(AbsoluteErrorPercentage, bins=nbins) # bin it into n = N//10 bins
x = x[:-1] + (x[1] - x[0])/2   # convert bin edges to centers
f = UnivariateSpline(x, p, s=nbins)
line2, = plt.plot(x, f(x))
lgd = plt.legend((line1, line2), ('NormXCorrErr', 'AbsoluteErrorPercentage'))

fig.savefig('Figures/TestingDataImpedancePrediction.png') 

fig = plt.figure()
plt.xlabel('Average RMSE and Average Absolute Error')
plt.ylabel('Probability')
plt.title('Average Error Plots')
p, x = np.histogram(AverageRMSE, bins=nbins) # bin it into n = N//10 bins
x = x[:-1] + (x[1] - x[0])/2   # convert bin edges to centers
f = UnivariateSpline(x, p, s=nbins)
line1, = plt.plot(x, f(x))

p, x = np.histogram(AverageAbsoluteError, bins=nbins) # bin it into n = N//10 bins
x = x[:-1] + (x[1] - x[0])/2   # convert bin edges to centers
f = UnivariateSpline(x, p, s=nbins)
line2, = plt.plot(x, f(x))
lgd = plt.legend((line1, line2), ('AverageRMSE', 'AverageAbsoluteError'))
fig.savefig('Figures/TestingDataImpedancePrediction.png')

# %%
a = 66;
print(a)
# Out:
# 66
